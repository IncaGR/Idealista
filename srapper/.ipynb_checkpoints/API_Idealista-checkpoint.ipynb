# %%
import asyncio
import os

# %%
import json
import requests
import base64

# %%
def get_token():
    API_KEY= "s70x87oty6xrmcjdepq1erdqquix4j8e"
    SECRET= "kytQ8FAQp71p"
    message = API_KEY + ":" + SECRET
    auth = "Basic " + base64.b64encode(message.encode("ascii")).decode("ascii")

    headers_dic = {"Authorization" : auth,
                   "Content-Type" : "application/x-www-form-urlencoded;charset=UTF-8"}

    params_dic = {"grant_type" : "client_credentials",
                  "scope" : "read"}

    r = requests.post("https://api.idealista.com/oauth/token",
                      headers = headers_dic,
                      params = params_dic)

    bearer_token = json.loads(r.text)['access_token']

    return bearer_token

# %%
def get_search():
    headers_dic = {"Authorization" : "Bearer " + TOKEN,
                   "Content-Type" : "application/x-www-form-urlencoded"}

    params_dic = {"operation" : "rent",
                  "locationId" : "0-EU-ES-01",
                  "propertyType" : "homes"}

    r = requests.post("https://api.idealista.com/3.5/es/search",
                      headers = headers_dic,
                      params = params_dic)

    result_json = json.loads(r.text)

    return result_json

# %%
TOKEN = get_token()

# %%
data = get_search()

# %%
data.keys()
# Out:
# dict_keys(['elementList', 'total', 'totalPages', 'actualPage', 'itemsPerPage', 'numPaginations', 'hiddenResults', 'summary', 'filter', 'alertName', 'lowerRangePosition', 'upperRangePosition', 'paginable'])

# %%
data['summary'] # saber lo que buscamos
# Out:
# ['Alquilar',
#  'Viviendas',
#  'Álava provincia',
#  'Todos los precios',
#  'Todos los tamaños']

# %%
data['elementList'][0]
# Out:
# {'propertyCode': '92289224',
#  'thumbnail': 'https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/78/5d/64/835881438.jpg',
#  'externalReference': '1BR ext',
#  'numPhotos': 10,
#  'floor': '3',
#  'price': 1050.0,
#  'propertyType': 'flat',
#  'operation': 'rent',
#  'size': 42.0,
#  'exterior': True,
#  'rooms': 1,
#  'bathrooms': 1,
#  'address': 'Avenida de Gasteiz, 45',
#  'province': 'Álava',
#  'municipality': 'Vitoria-Gasteiz',
#  'district': 'San Martín',
#  'country': 'es',
#  'latitude': 42.84766,
#  'longitude': -2.6820415,
#  'showAddress': True,
#  'url': 'https://www.idealista.com/inmueble/92289224/',
#  'description': 'Apartamento de 1 dormitorio exterior en pleno centro de Vitoria. Todos los gastos incluidos: luz, agua, calefacción e internet. ¡Sin permanencia! El apartamento es de obra nueva y tiene una capacidad máxima de 4 personas. Dispone de dos camas individuales o una de matrimonio en el dormitorio y un sofá cama doble en el salón. Tiene armarios y está climatizado (suelo radiante y aire acondicionado). Viene con TV en el salón y la cocina está equipada con electrodomésticos y menaje. Tiene un baño completo con ducha, artículos de aseo y secador de pelo. El edificio tiene servicio de atención online 24/7 y dispone de parking privado (se contrata por separado).  Está situado a solo 5 min del Casco Viejo de Vitoria y de la Catedral de María Inmaculada, junto a varias paradas de autobús (líneas 1, 5, 7, 8, 10) y a 150 metros del tranvía (estaciones Sancho el Sabio y Lovaina de la T1 y la T2). En la Avenida Gasteiz y sus inmediaciones encontrarás numerosas cafeterías y restaurantes. No tendrás que preocuparte de pagar las facturas. ¡Disfruta de toda la comodidad y flexibilidad en el centro de Vitoria! *Contrato renovable mensualmente y fianza de 500 euros.',
#  'hasVideo': False,
#  'status': 'good',
#  'newDevelopment': False,
#  'hasLift': True,
#  'parkingSpace': {'hasParkingSpace': True,
#   'isParkingSpaceIncludedInPrice': False,
#   'parkingSpacePrice': 120.0},
#  'priceByArea': 25.0,
#  'detailedType': {'typology': 'flat'},
#  'suggestedTexts': {'subtitle': 'San Martín, Vitoria-Gasteiz',
#   'title': 'Piso en Avenida de Gasteiz, 45'},
#  'hasPlan': False,
#  'has3DTour': False,
#  'has360': False,
#  'hasStaging': False,
#  'topNewDevelopment': False}
