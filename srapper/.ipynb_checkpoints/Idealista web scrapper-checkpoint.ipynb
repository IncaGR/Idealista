# %%
import requests
from bs4 import BeautifulSoup as bs
import time
import random
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import re
from datetime import date

# %%
# headers -> Ctrl + shift + i (pagina de desarrollador) -> network Ctrl + f5 -> primera pestaña -> request headers
# desde "accept" ponerlo en dict 
headers = {
"accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
"accept-encoding": "gzip, deflate, br",
"accept-language": "en-GB,en;q=0.9,en-US;q=0.8,ca;q=0.7,es;q=0.6,eo;q=0.5",
"cache-control": "no-cache",
"cookie": '''atuserid=%7B%22name%22%3A%22atuserid%22%2C%22val%22%3A%2268f673fe-430e-424d-9df0-0cd8699a34a7%22%2C%22options%22%3A%7B%22end%22%3A%222023-03-03T18%3A46%3A49.424Z%22%2C%22path%22%3A%22%2F%22%7D%7D; atidvisitor=%7B%22name%22%3A%22atidvisitor%22%2C%22val%22%3A%7B%22vrn%22%3A%22-582065-%22%7D%2C%22options%22%3A%7B%22path%22%3A%22%2F%22%2C%22session%22%3A15724800%2C%22end%22%3A15724800%7D%7D; didomi_token=...; euconsent-v2=CPTmlIAPTmlIAAHABBENB_CoAP_AAAAAAAAAF5wBAAIAAtAC2AvMAAABAaADAAEEQyUAGAAIIhlIAMAAQRDIQAYAAgiGOgAwABBEMJABgACCIYyADAAEEQxUAGAAIIhg.f_gAAAAAAAAA; _gcl_au=1.1.8146483.1643568415; _fbp=fb.1.1643568415299.2070506742; afUserId=58c2a54c-4375-4eb4-baca-6a6e48c65725-p; AF_SYNC=1643568416416; askToSaveAlertPopUp=true; _hjSessionUser_250321=eyJpZCI6ImU0N2FkYjkyLTgyMDMtNWU0Mi1iMTRiLWIzMzQzMDE0NTM0NiIsImNyZWF0ZWQiOjE2NDM1Njg1MjgzMzYsImV4aXN0aW5nIjp0cnVlfQ==; userUUID=6eadbb28-4981-4c13-abda-fd7fadaec832; SESSION=f1f80941eb4fade2~bda569d4-9873-4a74-80a2-5fd0ae1a6c25; contactbda569d4-9873-4a74-80a2-5fd0ae1a6c25="{'email':null,'phone':null,'phonePrefix':null,'friendEmails':null,'name':null,'message':null,'message2Friends':null,'maxNumberContactsAllow':10,'defaultMessage':true}"; cookieSearch-1="/alquiler-viviendas/barcelona/les-corts/les-corts/:1643650811421"; sendbda569d4-9873-4a74-80a2-5fd0ae1a6c25="{'friendsEmail':null,'email':null,'message':null}"; _hjIncludedInSessionSample=1; _hjSession_250321=eyJpZCI6IjYyNTE2ZTJjLWNkNTYtNDRkZS05NmJkLWQ4ZjYxYjQwMGE1NCIsImNyZWF0ZWQiOjE2NDM2NTEzNjU5MTEsImluU2FtcGxlIjp0cnVlfQ==; _hjAbsoluteSessionInProgress=0; _hjCachedUserAttributes=eyJhdHRyaWJ1dGVzIjp7ImlkX3BhZ2VMYW5ndWFnZSI6ImVzIiwiaWRfdXNlclJvbGUiOiIifSwidXNlcklkIjpudWxsfQ==; ABTasty=uid=s43fcyc0hr2z8nkz&fst=1643568412317&pst=1643568412317&cst=1643650069991&ns=2&pvt=35&pvis=13&th=; ABTastySession=mrasn=&sen=12&lp=https%253A%252F%252Fwww.idealista.com%252F; utag_main=v_id:017eac27920f001f94d41f93932f05072002f06a00978$_sn:3$_se:17$_ss:0$_st:1643653573939$dc_visit:2$ses_id:1643650066499%3Bexp-session$_pn:13%3Bexp-session$_prevVtSource:directTraffic%3Bexp-1643653668218$_prevVtCampaignCode:%3Bexp-1643653668218$_prevVtDomainReferrer:%3Bexp-1643653668218$_prevVtSubdomaninReferrer:%3Bexp-1643653668218$_prevVtUrlReferrer:%3Bexp-1643653668218$_prevVtCampaignLinkName:%3Bexp-1643653668218$_prevVtCampaignName:%3Bexp-1643653668218$_prevVtRecommendationId:%3Bexp-1643653668218$_prevCompletePageName:12%3A%3Adetail%3A%3A%3A%3A%3A%3Ahome%3Bexp-1643655375478$_prevLevel2:12%3Bexp-1643655375478$_prevAdId:94476328%3Bexp-1643655375489$_prevAdOriginTypeRecommended:undefined%3Bexp-1643653668228$dc_event:5%3Bexp-session$dc_region:us-east-1%3Bexp-session; cto_bundle=5izo9l9XUkgzNEJIYU9ITGFNWU5xMWp4YWoxNCUyRnFJN2dHbFJTbWRCVlpldHRFbjF4aFFaSmFvWHZvV3B2WCUyRmx1MEhiMUNQbDlUQmlPckkwdW51VTdTZjltc255c0ZjRng0d1c4MXVFVURBdUFXdEYwaSUyQnhtSlowY3oybzE4TkxtY2RVWmR3ZHJvbVJvUko1MmQxT1FJczJvV2clM0QlM0Q; datadome=v475FOZILU7oISIcQM..EhoU-BUZiH-ZFK2rcgXnvpb4HM05afYuAyFXtJCwx2Wz7bUmxBeuhegZikjdshl3ZtuSvzBOApWI_EnGCatwDUdNRGdY_Ox0oK6H5CgXTyT''',
"pragma": "no-cache",
"referer": "https://www.idealista.com/inmueble/95249555/",
"sec-ch-ua": '" Not;A Brand";v="99", "Google Chrome";v="97", "Chromium";v="97"',
"sec-ch-ua-mobile": "?0",
"sec-ch-ua-platform": '"Windows"',
"sec-fetch-dest": "document",
"sec-fetch-mode": "navigate",
"sec-fetch-site": "same-origin",
"sec-fetch-user": "?1",
"upgrade-insecure-requests": "1",
"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36"
    
}

# %% [markdown]
# ### Funcion usar ids y devolver caracteristicas inmueble:

# %%
def get_ids(headers,cp):
    '''
    Function that returns all the flats ids of certain zip code with fixed headers request.
    The function return a list with the ids.
    
    headers: needed to obtain response 200 (success).
    cp: zip code.
    proxies: proxy to try.
    
    Returns list of ids.
    '''
    cp = cp
    x = 1
    ids = []
    
    try:

        while True:
            url = f'https://www.idealista.com/buscar/alquiler-viviendas/{cp}/pagina-{x}.htm'
            r = requests.get(url, headers = headers)
            soup = bs(r.text,'lxml')

            pag_actual = int(soup.find('main', {'class':'listing-items'}).find('div',{'class':'pagination'}).find('li',{'class':'selected'}).text)

            if x == pag_actual:
                articles = soup.find('main', {'class':'listing-items'}).find_all('article')
            else:
                break

            for article in articles:
                id_piso = article.get('data-adid')  # get()  return the value of the key
                ids.append(id_piso)

        #     id_pisos =  [article.get('data-adid') for article in articles]  # get()  return the value of the key
            time.sleep(random.randint(2,4)*random.random()) #
        #     ids.append(id_pisos)

            x += 1

    except:

        print(r)
        
    return ids

# %%
def obtain_data_from_ids(ids,headers,cp):
    '''
    Function that return all the data from each add id from previous function "get_ids".
    It returns the data in dictionary format, ready to be converted to dataframe.
    
    ids = list of ids.
    headers = to avoid errors, response 200 (success)
    cp = zip code of the ids
    
    Returns a dic with id as a key.
    '''
    
    dic = {}
    x=1

    for i in ids:
        try:
        
            url = f"https://www.idealista.com/inmueble/{i}/"

            print("id:",i)

            r = requests.get(url,headers=headers) # añadimos parametro headers
            soup = bs(r.text,'lxml')  # formato mas legible
            titulo = soup.find('h1').text.strip() 
            localizacion = soup.find('span',{'class':'main-info__title-block'}).find("span").text
            precio = soup.find('div',{'class':'info-data'}).find('span').text.strip(' €/mes')
            if "." in precio:
                precio = precio.replace('.','') # falta formato int
                
            detalles = soup.find('section',{"id":"details"}).find("div",{"class":"details-property-feature-one"})
            caract = [det.text.strip() for det in detalles.find_all("li")]

            s = ' '.join(caract).lower()

            metros = re.search(r'\d\d\d m²|\d\d m²',s).group().replace(' m²','')
            # util = re.search(r'\d\d m² útiles',s).group()
            hab =  "".join(re.findall(r'\d hab|sin habitación',s))
            wc =  "".join(re.findall(r'\d baño',s))
            terraza = "".join(re.findall(r'terraza',s))
            balcon = "".join(re.findall(r'balcón|balcon',s))
            estado = "".join(re.findall(r'segunda mano/buen estado',s))
            year = "".join(re.findall(r'\d\d\d\d',s))
            armarios = "".join(re.findall(r'armarios',s))
            cocina = "".join(re.findall(r'cocina equipada|cocina sin equipar',s))
            amu = "".join(re.findall(r'amueblada|amueblado|sin amueblar',s))
            # noAmu = re.findall(r'sin amueblar',s)
            planta = "".join(re.findall(r'planta \d\d|planta \d|bajo',s))
            calefac = "".join(re.findall(r'no dispone de calefacción|calefacción',s))
            ascn = "".join(re.findall(r'con ascensor|sin ascensor',s))
            exterior = "".join(re.findall(r'exterior|interior',s))
        #     aire = "".join(re.findall(r'aire acondicionado',s))
            cp = cp
            extract_day = date.today()

            dic[i] = [titulo,localizacion,precio,metros,hab,wc,terraza,balcon,estado,year,armarios,cocina,amu,planta,calefac,ascn,exterior,cp,extract_day]

            time.sleep(random.randint(2,4)*random.random())
            print(r, "anuncio número:{}".format(x),sep="\n")
            
            x += 1
        
        except:
            print(r)
        
    return dic

# %%
def dic_to_df(dic):
    '''
    Transform dic from Idealista https://www.idealista.com/inmueble
    to a data frame.
    
    dic -> Dataframe
    '''
    colnames = ['name','zone','price','square_mt','rooms','wc','terraza','balcon','estado',\
     'año','armarios','cocina','amueblado','planta','calef','asc','exterior','cp','extract_day']
    df = pd.DataFrame.from_dict(dic, orient='index',columns=colnames)
    
    return df

# %%
def df_parse(df):
    '''
    Transform dataframe from Idealista https://www.idealista.com/inmueble
    to a clean data frame and convert the data types to int when posible.
    
    Dataframe -> Dataframe
    '''
    df['price'] = df.price.astype(int)
    df['square_mt'] = df.square_mt.astype(int)
    try:
        df ['rooms']=df.rooms.apply(lambda x: x.replace('sin habitación','0'))
        df ['rooms']=df.rooms.apply(lambda x: x.replace(' hab','')).astype(int)
    except:
        pass
    try:
        df ['wc']=df.wc.apply(lambda x: x.replace(' baño','')).astype(int)
    #     df ['wc']=df.rooms.apply(lambda x: x.replace(' hab','')).astype(int)
    except:
        pass
    df['terraza'] = df.terraza.apply(lambda x:  x.replace('terraza','1') if x == 'terraza' else '0').astype(int)
    df['balcon'] = df.balcon.apply(lambda x:  x.replace('balcón','1') if x == 'balcón' else '0').astype(int)
    df['armarios'] = df.armarios.apply(lambda x:  x.replace('armarios','1') if x == 'armarios' else '0').astype(int)
    df['cocina'] = df.cocina.apply(lambda x:  x.replace('cocina equipada','1') if x == 'cocina equipada' else '0').astype(int)
    df['amueblado'] = df.amueblado.apply(lambda x:  x.replace('amueblado','1') if x == 'amueblado' else '0').astype(int)
    df['calef'] = df.calef.apply(lambda x:  x.replace('calefacción','1') if x == 'calefacción' else '0').astype(int)
    df['asc'] = df.asc.apply(lambda x:  x.replace('con ascensor','1') if x == 'con ascensor' else '0').astype(int)
    df['exterior'] = df.exterior.apply(lambda x:  x.replace('exterior','1') if x == 'exterior' else '0').astype(int)
    try:
        df['planta'] = df.planta.apply(lambda x: x.replace('planta ',''))
        df['planta'] = df.planta.apply(lambda x: '0' if x == "" else x)
        df['planta'] = df.planta.apply(lambda x: '0' if x == "bajo" else x)
        df['planta'] = df.planta.astype(int)
    except:
        pass
    df['cp'] = df.cp.astype(str)
    
    return df

# %%
# Falta probar

# import requests
# import requests_html
# from lxml.html import fromstring


# def get_proxies():
#     url = 'https://free-proxy-list.net/'
#     response = requests.get(url)
#     parser = fromstring(response.text)
#     proxies = set()
#     for i in parser.xpath('//tbody/tr')[:250]:
#         if i.xpath('.//td[7][contains(text(),"yes")]'):
#             #Grabbing IP and corresponding PORT
#             proxy = ":".join([i.xpath('.//td[1]/text()')[0], i.xpath('.//td[2]/text()')[0]])
#             proxies.add(proxy)
#     return proxies

# %%
# p = get_proxies()

# %%
# p

# %%
cp = ["{:05d}".format(i) for i in range(8001,8043)]
# cp

# %%
url_cp = "https://www.idealista.com/buscar/alquiler-viviendas/{}/".format(cp[0])

# %%
url_cp
# Out:
# 'https://www.idealista.com/buscar/alquiler-viviendas/08001/'

# %%
ids_08001 = get_ids(headers,"08001")

# %%
ids_08001
# Out:
# ['96713367',
#  '96462726',
#  '92778979',
#  '96705914',
#  '96711110',
#  '96705959',
#  '96711108',
#  '96698319',
#  '96711101',
#  '40552887',
#  '96711113',
#  '96611325',
#  '96711076',
#  '96605872',
#  '96708461',
#  '93961980',
#  '96706304',
#  '85079513',
#  '96705691',
#  '96605850',
#  '96705398',
#  '39062156',
#  '35405049',
#  '96010981',
#  '84464110',
#  '91874854',
#  '96704411',
#  '94555537',
#  '96703944',
#  '96644945',
#  '96703620',
#  '95434808',
#  '96702132',
#  '96675023',
#  '95696234',
#  '90544885',
#  '96175576',
#  '96698116',
#  '96697399',
#  '28868822',
#  '96067821',
#  '85969039',
#  '88707961',
#  '85985033',
#  '94124002',
#  '96588961',
#  '96586910',
#  '92711464',
#  '96472062',
#  '96442968',
#  '96442967',
#  '96442966',
#  '96442961',
#  '96442949',
#  '96442929',
#  '96442927',
#  '96442937',
#  '96442942',
#  '96442936',
#  '96442921',
#  '96442890',
#  '96394926',
#  '95891759',
#  '81320003',
#  '81318179',
#  '96466568',
#  '40159511',
#  '88843045',
#  '96601395',
#  '96436948',
#  '96638042',
#  '96232053',
#  '92783113',
#  '96611456',
#  '96446270',
#  '96442962',
#  '96442920',
#  '96442900',
#  '96442866',
#  '84049621',
#  '87191763',
#  '95972651',
#  '95972646',
#  '95972654',
#  '95916193',
#  '85998518',
#  '95266056',
#  '95240417',
#  '91827157',
#  '91827161',
#  '88493087',
#  '93518739',
#  '86674421',
#  '88462293',
#  '96640304',
#  '96459844',
#  '83750475',
#  '96219805',
#  '40509048',
#  '95228143',
#  '90824822',
#  '88741617',
#  '96110533',
#  '95250731',
#  '91285223',
#  '96533461',
#  '86381199',
#  '86982464',
#  '95588814',
#  '85250916',
#  '86381302',
#  '85993539',
#  '33912432',
#  '87765100',
#  '95618934',
#  '96533800',
#  '96386380',
#  '34085091',
#  '96179425',
#  '96605348',
#  '81599974',
#  '96424808',
#  '88814065',
#  '96180889',
#  '90807688',
#  '88842459',
#  '1690095',
#  '95705652',
#  '93796398',
#  '92927120',
#  '96609632',
#  '91913093',
#  '88165443',
#  '94490194',
#  '94316853',
#  '84539742',
#  '96372813',
#  '96322452',
#  '799431',
#  '95505897',
#  '96080002',
#  '95874695',
#  '94397000',
#  '96197817',
#  '95719042',
#  '31654249',
#  '96481220',
#  '83650389',
#  '96079436',
#  '95930066',
#  '95507989',
#  '96430655',
#  '96441193',
#  '40579547',
#  '96460536',
#  '92313882',
#  '30630394',
#  '96694435',
#  '90576564',
#  '95598250',
#  '95893670',
#  '95866167',
#  '96287094',
#  '95975876',
#  '96423108',
#  '96407507']

# %%
data_ids_08001 = obtain_data_from_ids(ids_08001,headers,cp="08001")
# Out:
# id: 96713367
# <Response [200]>
# anuncio número:2
# id: 96462726
# <Response [200]>
# anuncio número:3
# id: 92778979
# <Response [200]>
# anuncio número:4
# id: 96705914
# <Response [200]>
# anuncio número:5
# id: 96711110
# <Response [200]>
# anuncio número:6
# id: 96705959
# <Response [200]>
# anuncio número:7
# id: 96711108
# <Response [200]>
# anuncio número:8
# id: 96698319
# <Response [200]>
# anuncio número:9
# id: 96711101
# <Response [200]>
# anuncio número:10
# id: 40552887
# <Response [200]>
# anuncio número:11
# id: 96711113
# <Response [200]>
# anuncio número:12
# id: 96611325
# <Response [200]>
# anuncio número:13
# id: 96711076
# <Response [200]>
# anuncio número:14
# id: 96605872
# <Response [200]>
# anuncio número:15
# id: 96708461
# <Response [200]>
# anuncio número:16
# id: 93961980
# <Response [200]>
# anuncio número:17
# id: 96706304
# <Response [200]>
# anuncio número:18
# id: 85079513
# <Response [200]>
# anuncio número:19
# <Response [200]>
# anuncio número:311
# id: 96424808
# <Response [200]>
# anuncio número:312
# id: 88814065
# <Response [200]>
# anuncio número:313
# id: 96180889
# <Response [200]>
# anuncio número:314
# id: 90807688
# <Response [200]>
# anuncio número:315
# id: 88842459
# <Response [200]>
# anuncio número:316
# id: 1690095
# <Response [200]>
# anuncio número:317
# id: 95705652
# <Response [200]>
# anuncio número:318
# id: 93796398
# <Response [200]>
# anuncio número:319
# id: 92927120
# <Response [200]>
# anuncio número:320
# id: 96609632
# <Response [200]>
# anuncio número:321
# id: 91913093
# <Response [200]>
# anuncio número:322
# id: 88165443
# <Response [200]>
# anuncio número:323
# id: 94490194
# <Response [200]>
# anuncio número:324
# id: 94316853
# <Response [200]>
# anuncio número:325
# id: 84539742
# <Response [200]>
# anuncio número:326
# id: 96372813
# <Response [200]>
# anuncio número:327
# id: 96322452
# <Response [200]>
# anuncio número:328
# id: 799431
# <Response [200]>
# anuncio número:329
# id: 95505897
# <Response [200]>
# anuncio número:330
# id: 96080002
# <Response [200]>
# anuncio número:331
# id: 95874695
# <Response [200]>
# anuncio número:332
# id: 94397000
# <Response [200]>
# anuncio número:333
# id: 96197817
# <Response [200]>
# anuncio número:334
# id: 95719042
# <Response [200]>
# anuncio número:335
# id: 31654249
# <Response [200]>
# anuncio número:336
# id: 96481220
# <Response [200]>
# anuncio número:337
# id: 83650389
# <Response [200]>
# anuncio número:338
# id: 96079436
# <Response [200]>
# anuncio número:339
# id: 95930066
# <Response [200]>
# anuncio número:340
# id: 95507989
# <Response [200]>
# anuncio número:341
# id: 96430655
# <Response [200]>
# anuncio número:342
# id: 96441193
# <Response [200]>
# anuncio número:343
# id: 40579547
# <Response [200]>
# anuncio número:344
# id: 96460536
# <Response [200]>
# anuncio número:345
# id: 92313882
# <Response [200]>
# anuncio número:346
# id: 30630394
# <Response [200]>
# anuncio número:347
# id: 96694435
# <Response [200]>
# anuncio número:348
# id: 90576564
# <Response [200]>
# anuncio número:349
# id: 95598250
# <Response [200]>
# anuncio número:350
# id: 95893670
# <Response [200]>
# anuncio número:351
# id: 95866167
# <Response [200]>
# anuncio número:352
# id: 96287094
# <Response [200]>
# anuncio número:353
# id: 95975876
# <Response [200]>
# anuncio número:354
# id: 96423108
# <Response [200]>
# anuncio número:355
# id: 96407507
# <Response [200]>
# anuncio número:356

# %%
data_ids_08001
# Out:
# {'96713367': ['Alquiler de Piso en calle de la Riera Alta, 10',
#   'El Raval, Barcelona',
#   '950',
#   '45',
#   '2 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 5',
#   '',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96462726': ['Alquiler de Piso en calle Joaquín Costa',
#   'El Raval, Barcelona',
#   '1350',
#   '70',
#   '2 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '92778979': ['Alquiler de Piso en El Raval',
#   'Ciutat Vella, Barcelona',
#   '1150',
#   '67',
#   '2 hab',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   '',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96705914': ['Alquiler de Piso en El Raval',
#   'Ciutat Vella, Barcelona',
#   '1100',
#   '55',
#   '2 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'sin ascensor',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96711110': ['Alquiler de Piso en calle de la Riereta',
#   'El Raval, Barcelona',
#   '1600',
#   '70',
#   '1 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   '',
#   '',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96705959': ['Alquiler de Piso en El Raval',
#   'Ciutat Vella, Barcelona',
#   '1100',
#   '55',
#   '2 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'sin ascensor',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96711108': ['Alquiler de Piso en calle de la Riereta',
#   'El Raval, Barcelona',
#   '1600',
#   '80',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   '',
#   '',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96698319': ['Alquiler de Piso en calle de la Riereta',
#   'El Raval, Barcelona',
#   '1200',
#   '48',
#   '2 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '2021',
#   'armarios',
#   'cocina equipada',
#   'sin amueblar',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96711101': ['Alquiler de Piso en calle de la Riereta',
#   'El Raval, Barcelona',
#   '1600',
#   '70',
#   '1 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   '',
#   '',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '40552887': ['Alquiler de Piso en El Raval',
#   'Ciutat Vella, Barcelona',
#   '2650',
#   '93',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   '',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96711113': ['Alquiler de Piso en calle de la Riereta',
#   'El Raval, Barcelona',
#   '1600',
#   '80',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   '',
#   '',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96611325': ['Alquiler de Piso en calle de la Reina Amàlia',
#   'El Raval, Barcelona',
#   '1800',
#   '80',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '2020',
#   'armarios',
#   '',
#   '',
#   'planta 2',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96711076': ['Alquiler de Piso en calle Joaquín Costa',
#   'El Raval, Barcelona',
#   '950',
#   '45',
#   '1 hab',
#   '2 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '1850',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96605872': ['Alquiler de Piso en calle del Príncep de Viana',
#   'El Raval, Barcelona',
#   '750',
#   '35',
#   '1 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   '',
#   '',
#   'planta 1',
#   'no dispone de calefacción',
#   'con ascensor',
#   'interior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96708461': ['Alquiler de Piso en Lluna, 24',
#   'El Raval, Barcelona',
#   '700',
#   '52',
#   '2 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '1925',
#   '',
#   'cocina sin equipar',
#   'sin amueblar',
#   'planta 5',
#   '',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '93961980': ['Alquiler de Piso en calle dels Tallers',
#   'El Raval, Barcelona',
#   '2750',
#   '89',
#   '2 hab',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '1890',
#   'armarios',
#   '',
#   '',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96706304': ['Alquiler de Piso en vistalegre',
#   'El Raval, Barcelona',
#   '650',
#   '45',
#   '1 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina sin equipar',
#   'sin amueblar',
#   'planta 2',
#   '',
#   'sin ascensor',
#   'interior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '85079513': ['Alquiler de Piso en calle de Gravina',
#   'El Raval, Barcelona',
#   '2650',
#   '94',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '1890',
#   'armarios',
#   '',
#   '',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96705691': ["Alquiler de Piso en calle de l'Arc de Sant Agustí",
#   'El Raval, Barcelona',
#   '2000',
#   '100',
#   '2 hab',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'sin amueblar',
#   'planta 1',
#   'calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96605850': ['Alquiler de Piso en calle de la Reina Amàlia',
#   'El Raval, Barcelona',
#   '1800',
#   '80',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '2020',
#   'armarios',
#   '',
#   '',
#   'bajo',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96705398': ['Alquiler de Estudio en calle de la Reina Amàlia, 5',
#   'El Raval, Barcelona',
#   '850',
#   '40',
#   'sin habitación',
#   '1 baño',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'bajo',
#   '',
#   'sin ascensor',
#   'interior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '39062156': ["Alquiler de Piso en calle de l'Aurora",
#   'El Raval, Barcelona',
#   '1150',
#   '65',
#   '2 hab',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '1845',
#   'armarios',
#   '',
#   '',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '35405049': ['Alquiler de Piso en calle dels Salvador',
#   'El Raval, Barcelona',
#   '725',
#   '47',
#   '1 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96010981': ['Alquiler de Piso en calle de Gravina',
#   'El Raval, Barcelona',
#   '2500',
#   '110',
#   '3 hab',
#   '3 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 2',
#   'calefacción',
#   'con ascensor',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '84464110': ['Alquiler de Piso en calle de Pelayo, Barcelona',
#   "La Dreta de l'Eixample, Barcelona",
#   '2750',
#   '95',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 4',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '91874854': ['Alquiler de Piso en Marques de Barberà',
#   'El Raval, Barcelona',
#   '1470',
#   '125',
#   '3 hab',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'sin amueblar',
#   '',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96704411': ['Alquiler de Piso en El Raval',
#   'Ciutat Vella, Barcelona',
#   '700',
#   '55',
#   '2 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'sin amueblar',
#   'planta 1',
#   '',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '94555537': ['Alquiler de Piso en El Raval',
#   'Ciutat Vella, Barcelona',
#   '1300',
#   '65',
#   '3 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'sin amueblar',
#   'planta 2',
#   '',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96703944': ['Alquiler de Piso en calle del Príncep de Viana',
#   'El Raval, Barcelona',
#   '875',
#   '60',
#   '1 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 4',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96644945': ['Alquiler de Piso en calle del Cid',
#   'El Raval, Barcelona',
#   '1050',
#   '67',
#   '2 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '1975',
#   '',
#   '',
#   '',
#   'planta 3',
#   'no dispone de calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96703620': ['Alquiler de Piso en calle de Sant Antoni Abat',
#   'El Raval, Barcelona',
#   '1000',
#   '50',
#   '1 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '1841',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 4',
#   'calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95434808': ['Alquiler de Piso en calle de la Reina Amàlia, 11',
#   'El Raval, Barcelona',
#   '1600',
#   '80',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '2020',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96702132': ['Alquiler de Piso en calle de Lancaster',
#   'El Raval, Barcelona',
#   '1767',
#   '48',
#   '2 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   '',
#   'sin ascensor',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96675023': ['Alquiler de Dúplex en lleo',
#   'El Raval, Barcelona',
#   '1250',
#   '90',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'bajo',
#   'calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95696234': ['Alquiler de Piso en calle de Picalquers',
#   'El Raval, Barcelona',
#   '750',
#   '50',
#   '2 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'sin ascensor',
#   'interior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '90544885': ['Alquiler de Piso en El Raval',
#   'Ciutat Vella, Barcelona',
#   '1650',
#   '70',
#   '2 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '2019',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96175576': ['Alquiler de Piso en calle de les Carretes',
#   'El Raval, Barcelona',
#   '1150',
#   '55',
#   '2 hab',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 2',
#   '',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96698116': ['Alquiler de Piso en El Raval',
#   'Ciutat Vella, Barcelona',
#   '760',
#   '53',
#   '2 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '1900',
#   '',
#   '',
#   '',
#   'planta 1',
#   'no dispone de calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96697399': ['Alquiler de Estudio en calle de L´ARC DE SANT AGUSTÍ',
#   'El Raval, Barcelona',
#   '2001',
#   '110',
#   'sin habitación',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 6',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '28868822': ['Alquiler de Estudio en calle Cera',
#   'El Raval, Barcelona',
#   '600',
#   '28',
#   'sin habitación',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '1900',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 2',
#   'calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '90802867': ['Alquiler de Piso en El Raval',
#   'Ciutat Vella, Barcelona',
#   '1650',
#   '100',
#   '3 hab',
#   '2 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 4',
#   '',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '32516811': ['Alquiler de Piso en calle de sant pau',
#   'El Raval, Barcelona',
#   '925',
#   '50',
#   '1 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 4',
#   'no dispone de calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96694606': ['Alquiler de Piso en reina amalia, 13',
#   'El Raval, Barcelona',
#   '1700',
#   '80',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '2021',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 2',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '87471104': ['Alquiler de Piso en calle de les Carretes, 21',
#   'El Raval, Barcelona',
#   '1150',
#   '65',
#   '2 hab',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96693908': ['Alquiler de Piso en gravina, 6',
#   'El Raval, Barcelona',
#   '2650',
#   '94',
#   '2 hab',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96693291': ['Alquiler de Piso en calle de Sant Pau',
#   'El Raval, Barcelona',
#   '995',
#   '36',
#   '1 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina sin equipar',
#   'sin amueblar',
#   'planta 2',
#   'no dispone de calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95866378': ['Alquiler de Dúplex en BISBE LAGUARDA',
#   'El Raval, Barcelona',
#   '800',
#   '50',
#   '1 hab',
#   '1 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '1918',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'bajo',
#   'no dispone de calefacción',
#   'sin ascensor',
#   'interior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96691638': ['Alquiler de Estudio en plaza de pedró',
#   'El Raval, Barcelona',
#   '605',
#   '28',
#   'sin habitación',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '2009',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96688431': ['Alquiler de Piso en calle de la Unió',
#   'El Raval, Barcelona',
#   '1215',
#   '17',
#   '1 hab',
#   '2 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   '',
#   'con ascensor',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96688391': ['Alquiler de Piso en calle de la Unió',
#   'El Raval, Barcelona',
#   '1073',
#   '11',
#   '1 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   '',
#   'con ascensor',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96688388': ['Alquiler de Piso en calle de la Unió',
#   'El Raval, Barcelona',
#   '1230',
#   '17',
#   '1 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 2',
#   '',
#   'con ascensor',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96688324': ['Alquiler de Piso en calle de la Unió',
#   'El Raval, Barcelona',
#   '1290',
#   '17',
#   '1 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   '',
#   'con ascensor',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96687272': ['Alquiler de Piso en calle Ferlandina',
#   'El Raval, Barcelona',
#   '900',
#   '75',
#   '3 hab',
#   '1 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '1920',
#   '',
#   'cocina sin equipar',
#   'sin amueblar',
#   'planta 1',
#   'no dispone de calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96686573': ['Alquiler de Estudio en calle de l´ARC DE SANT AGUSTÍ',
#   'El Raval, Barcelona',
#   '2000',
#   '110',
#   'sin habitación',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96682134': ['Alquiler de Piso en calle de la Cera',
#   'El Raval, Barcelona',
#   '1095',
#   '64',
#   '2 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'no dispone de calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '93061880': ['Alquiler de Piso en aurora, 10',
#   'El Raval, Barcelona',
#   '670',
#   '44',
#   '1 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   '',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95801316': ['Alquiler de Piso en PRINCEP DE VIANA, 21',
#   'El Raval, Barcelona',
#   '1250',
#   '55',
#   '1 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'bajo',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96675488': ["Alquiler de Estudio en calle de l'Arc de Sant Agustí",
#   'El Raval, Barcelona',
#   '2000',
#   '110',
#   'sin habitación',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 2',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96673920': ['Alquiler de Piso en unio',
#   'El Raval, Barcelona',
#   '1300',
#   '50',
#   '1 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 4',
#   'calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96666341': ['Alquiler de Piso en calle de Gravina',
#   'El Raval, Barcelona',
#   '2500',
#   '81',
#   '2 hab',
#   '1 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '1890',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96659770': ['Alquiler de Piso en calle de Sant Antoni Abat',
#   'El Raval, Barcelona',
#   '1500',
#   '53',
#   '1 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '1900',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   'no dispone de calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '87206636': ['Alquiler de Piso en Paloma',
#   'El Raval, Barcelona',
#   '1350',
#   '65',
#   '2 hab',
#   '2 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   '',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '87253271': ['Alquiler de Piso en calle del Doctor Dou',
#   'El Raval, Barcelona',
#   '1380',
#   '87',
#   '2 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina sin equipar',
#   'sin amueblar',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95556371': ['Alquiler de Piso en calle de la Reina Amàlia',
#   'El Raval, Barcelona',
#   '1900',
#   '80',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '2021',
#   'armarios',
#   '',
#   '',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95556368': ['Alquiler de Piso en calle de la Reina Amàlia',
#   'El Raval, Barcelona',
#   '2100',
#   '97',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '2021',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'bajo',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96102249': ['Alquiler de Piso en El Raval',
#   'Ciutat Vella, Barcelona',
#   '1200',
#   '83',
#   '1 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '1850',
#   '',
#   'cocina equipada',
#   'sin amueblar',
#   'planta 1',
#   'calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95960504': ['Alquiler de Piso en calle de la Reina Amàlia',
#   'El Raval, Barcelona',
#   '1900',
#   '80',
#   '1 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '2021',
#   '',
#   'cocina sin equipar',
#   'sin amueblar',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96646603': ['Alquiler de Piso en calle de la Reina Amàlia, 11',
#   'El Raval, Barcelona',
#   '1600',
#   '80',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '2021',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 6',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '87359507': ['Alquiler de Piso en calle de Joaquín Costa',
#   'El Raval, Barcelona',
#   '1350',
#   '61',
#   '2 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 2',
#   'calefacción',
#   'con ascensor',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '81425280': ['Alquiler de Piso en calle de Sant Vicenç',
#   'El Raval, Barcelona',
#   '1600',
#   '80',
#   '3 hab',
#   '3 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '88579690': ['Alquiler de Piso en calle de Joaquín Costa',
#   'El Raval, Barcelona',
#   '1350',
#   '70',
#   '2 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 4',
#   'calefacción',
#   'con ascensor',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96375836': ['Alquiler de Piso en calle de Gravina',
#   'El Raval, Barcelona',
#   '2500',
#   '93',
#   '2 hab',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '2018',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 2',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95728679': ['Alquiler de Piso en calle de Sant Pau',
#   'El Raval, Barcelona',
#   '1200',
#   '55',
#   '1 hab',
#   '1 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina sin equipar',
#   'sin amueblar',
#   'planta 1',
#   'no dispone de calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95990609': ['Alquiler de Piso en calle de Sant Pau',
#   'El Raval, Barcelona',
#   '1100',
#   '55',
#   '1 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina sin equipar',
#   'sin amueblar',
#   'planta 1',
#   'no dispone de calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96419367': ['Alquiler de Piso en calle de Pelai',
#   "La Dreta de l'Eixample, Barcelona",
#   '2500',
#   '94',
#   '2 hab',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 4',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96661360': ['Alquiler de Piso en calle de la Reina Amàlia, 9',
#   'El Raval, Barcelona',
#   '1700',
#   '80',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '2021',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96646501': ['Alquiler de Piso en calle de la Reina Amàlia, 13',
#   'El Raval, Barcelona',
#   '1800',
#   '82',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '2021',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95721255': ['Alquiler de Piso en El Raval',
#   'Ciutat Vella, Barcelona',
#   '1800',
#   '60',
#   '2 hab',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 4',
#   '',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '94635413': ['Alquiler de Piso en calle del Carme, 9',
#   'El Raval, Barcelona',
#   '1195',
#   '75',
#   '1 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   'calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '39964620': ['Alquiler de Piso en ronda de Sant Antoni',
#   'El Raval, Barcelona',
#   '1350',
#   '80',
#   '3 hab',
#   '1 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   '',
#   '',
#   'planta 4',
#   '',
#   'con ascensor',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '93266747': ['Alquiler de Estudio en calle del Pintor Fortuny, 23',
#   'El Raval, Barcelona',
#   '702',
#   '41',
#   'sin habitación',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   'interior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '93942164': ['Alquiler de Piso en calle de la Cera',
#   'El Raval, Barcelona',
#   '1250',
#   '40',
#   '1 hab',
#   '1 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 2',
#   'calefacción',
#   '',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95882685': ['Alquiler de Estudio en carme',
#   'El Raval, Barcelona',
#   '850',
#   '68',
#   'sin habitación',
#   '1 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   'interior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96515728': ['Alquiler de Piso en plaza del Pedró',
#   'El Raval, Barcelona',
#   '1215',
#   '167',
#   '4 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '1923',
#   'armarios',
#   'cocina equipada',
#   'sin amueblar',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '81880361': ['Alquiler de Piso en calle de les Carretes, 73',
#   'El Raval, Barcelona',
#   '900',
#   '45',
#   '1 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 2',
#   '',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '39345543': ['Alquiler de Piso en calle de joaquín costa',
#   'El Raval, Barcelona',
#   '1450',
#   '60',
#   '3 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95607497': ['Alquiler de Piso en calle de Picalquers',
#   'El Raval, Barcelona',
#   '895',
#   '27',
#   '1 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 2',
#   'calefacción',
#   '',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96611318': ['Alquiler de Piso en calle de la Reina Amàlia',
#   'El Raval, Barcelona',
#   '1800',
#   '80',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '2020',
#   'armarios',
#   '',
#   '',
#   'bajo',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96661299': ['Alquiler de Estudio en calle dels Tallers',
#   'El Raval, Barcelona',
#   '937',
#   '58',
#   'sin habitación',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   '',
#   '',
#   'planta 4',
#   '',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96645661': ['Alquiler de Estudio en calle de la Reina Amàlia',
#   'El Raval, Barcelona',
#   '860',
#   '55',
#   'sin habitación',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'bajo',
#   'no dispone de calefacción',
#   '',
#   'interior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96627996': ['Alquiler de Piso en calle de la Reina Amàlia, 13',
#   'El Raval, Barcelona',
#   '1700',
#   '82',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '2021',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96585782': ['Alquiler de Piso en calle de la Reina Amàlia, 11',
#   'El Raval, Barcelona',
#   '1600',
#   '80',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '2021',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 2',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96513758': ['Alquiler de Piso en calle de la Reina Amàlia, 9',
#   'El Raval, Barcelona',
#   '1600',
#   '80',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '2021',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 2',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96470549': ['Alquiler de Piso en calle de la Reina Amàlia, 11',
#   'El Raval, Barcelona',
#   '1700',
#   '80',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '2021',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 4',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96589177': ['Alquiler de Piso en calle dels Salvador',
#   'El Raval, Barcelona',
#   '650',
#   '42',
#   '1 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '1905',
#   '',
#   '',
#   '',
#   'planta 5',
#   '',
#   'sin ascensor',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96589163': ['Alquiler de Piso en calle de Requesens',
#   'El Raval, Barcelona',
#   '720',
#   '47',
#   '2 hab',
#   '1 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   '',
#   '',
#   'planta 4',
#   '',
#   'sin ascensor',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96489494': ['Alquiler de Piso en calle Nou de la Rambla',
#   'El Raval, Barcelona',
#   '1050',
#   '85',
#   '2 hab',
#   '2 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '1974',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   'no dispone de calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96662485': ['Alquiler de Piso en calle de Gravina',
#   'El Raval, Barcelona',
#   '2750',
#   '94',
#   '3 hab',
#   '3 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   '',
#   '',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96482386': ['Alquiler de Piso en calle del Lleó',
#   'El Raval, Barcelona',
#   '800',
#   '70',
#   '1 hab',
#   '1 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '1945',
#   '',
#   'cocina equipada',
#   'sin amueblar',
#   'bajo',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95826452': ['Alquiler de Piso en calle de Sant Antoni Abat',
#   'El Raval, Barcelona',
#   '895',
#   '35',
#   '1 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 2',
#   'calefacción',
#   '',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '85345989': ['Alquiler de Piso en rambla del Raval',
#   'El Raval, Barcelona',
#   '875',
#   '35',
#   '1 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   'calefacción',
#   '',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '90664412': ['Alquiler de Estudio en calle de la Riera Alta',
#   'El Raval, Barcelona',
#   '1390',
#   '40',
#   'sin habitación',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 4',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96450819': ['Alquiler de Piso en calle de la Reina Amàlia',
#   'El Raval, Barcelona',
#   '1800',
#   '85',
#   '2 hab',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '2020',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 4',
#   '',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96447896': ['Alquiler de Piso en calle de la Reina Amàlia',
#   'El Raval, Barcelona',
#   '1900',
#   '80',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '2020',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'bajo',
#   '',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96277934': ['Alquiler de Piso en GRAVINA, 26',
#   "La Dreta de l'Eixample, Barcelona",
#   '2600',
#   '82',
#   '2 hab',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 5',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '90636971': ['Alquiler de Piso en calle Gravina, 8',
#   'El Raval, Barcelona',
#   '2650',
#   '94',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96670501': ["Alquiler de Estudio en calle de l'Arc de Sant Agustí",
#   'El Raval, Barcelona',
#   '2000',
#   '110',
#   'sin habitación',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 4',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96664483': ['Alquiler de Estudio en calle de L´arc de sant agustí',
#   'El Raval, Barcelona',
#   '2000',
#   '110',
#   'sin habitación',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 11',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '94818628': ['Alquiler de Piso en calle de Gravina',
#   'El Raval, Barcelona',
#   '2400',
#   '93',
#   '2 hab',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95486849': ['Alquiler de Piso en calle de la Reina Amàlia',
#   'El Raval, Barcelona',
#   '1700',
#   '80',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '94047217': ['Alquiler de Ático en calle del Bisbe Laguarda',
#   'El Raval, Barcelona',
#   '1100',
#   '70',
#   '1 hab',
#   '2 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   '',
#   '',
#   'planta 6',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '86413117': ['Alquiler de Piso en calle del Pintor Fortuny',
#   'El Raval, Barcelona',
#   '2800',
#   '220',
#   '3 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '1918',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '40508904': ['Alquiler de Piso en Gravina',
#   'El Raval, Barcelona',
#   '2100',
#   '80',
#   '2 hab',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '1940',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 2',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '87117468': ["Alquiler de Piso en calle de l'Aurora",
#   'El Raval, Barcelona',
#   '1000',
#   '78',
#   '1 hab',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '1950',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 2',
#   'calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96094087': ['Alquiler de Ático en lleo',
#   'El Raval, Barcelona',
#   '1200',
#   '96',
#   '1 hab',
#   '1 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '1849',
#   '',
#   'cocina equipada',
#   'sin amueblar',
#   'planta 4',
#   'calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '85054152': ['Alquiler de Piso en calle Sant Pau, 47',
#   'El Raval, Barcelona',
#   '1100',
#   '50',
#   '1 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   'calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95909203': ['Alquiler de Piso en calle del Marquès de Barberà, 27',
#   'El Raval, Barcelona',
#   '1400',
#   '49',
#   '1 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '94961123': ['Alquiler de Piso en calle del Marquès de Barberà, 25',
#   'El Raval, Barcelona',
#   '1400',
#   '60',
#   '2 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '92526142': ['Alquiler de Piso en calle del Marquès de Barberà, 27',
#   'El Raval, Barcelona',
#   '1400',
#   '65',
#   '2 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '91808699': ['Alquiler de Piso en calle del Marquès de Barberà, 2',
#   'El Raval, Barcelona',
#   '1470',
#   '135',
#   '4 hab',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'sin amueblar',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '84093258': ['Alquiler de Piso en calle de Sant Bartomeu',
#   'El Raval, Barcelona',
#   '900',
#   '22',
#   '1 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96662584': ['Alquiler de Piso en calle de la Reina Amàlia',
#   'El Raval, Barcelona',
#   '750',
#   '64',
#   '1 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '1900',
#   '',
#   'cocina equipada',
#   'amueblado',
#   '',
#   'calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '85381348': ["Alquiler de Piso en calle de l'Arc de Sant Agustí",
#   'El Raval, Barcelona',
#   '1150',
#   '58',
#   '2 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   '',
#   '',
#   'planta 6',
#   '',
#   'con ascensor',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96639627': ['Alquiler de Piso en calle de la Reina Amàlia',
#   'El Raval, Barcelona',
#   '1800',
#   '70',
#   '2 hab',
#   '2 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96358186': ['Alquiler de Piso en calle de Gravina',
#   'El Raval, Barcelona',
#   '2500',
#   '84',
#   '2 hab',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '1890',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '39345411': ["Alquiler de Piso en calle de l'hospital",
#   'El Raval, Barcelona',
#   '950',
#   '45',
#   '1 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   '',
#   'calefacción',
#   '',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96626267': ['Alquiler de Piso en calle de les Cabres',
#   'El Raval, Barcelona',
#   '1400',
#   '44',
#   '2 hab',
#   '2 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '1870',
#   '',
#   'cocina equipada',
#   'sin amueblar',
#   '',
#   '',
#   'sin ascensor',
#   'interior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96397979': ['Alquiler de Dúplex en calle del Lleó, 5',
#   'El Raval, Barcelona',
#   '800',
#   '90',
#   '1 hab',
#   '1 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'sin amueblar',
#   'bajo',
#   '',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96639633': ['Alquiler de Piso en calle de la Reina Amàlia',
#   'El Raval, Barcelona',
#   '2000',
#   '70',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   '',
#   '',
#   'bajo',
#   'calefacción',
#   '',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96622717': ['Alquiler de Piso en El Raval',
#   'Ciutat Vella, Barcelona',
#   '1300',
#   '55',
#   '2 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'bajo',
#   '',
#   'con ascensor',
#   'interior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '93415908': ['Alquiler de Piso en calle de les Cabres, 5',
#   'El Raval, Barcelona',
#   '1000',
#   '37',
#   '1 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 2',
#   'calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '86793938': ['Alquiler de Piso en calle Joaquín Costa',
#   'El Raval, Barcelona',
#   '1490',
#   '70',
#   '3 hab',
#   '2 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '88564735': ['Alquiler de Piso en Joaquín Costa',
#   'El Raval, Barcelona',
#   '1075',
#   '45',
#   '1 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 5',
#   'calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '86808398': ['Alquiler de Piso en calle Joaquin',
#   'El Raval, Barcelona',
#   '1490',
#   '70',
#   '3 hab',
#   '2 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 2',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '86811318': ['Alquiler de Piso en C/Joaquín Costa',
#   'El Raval, Barcelona',
#   '1490',
#   '70',
#   '3 hab',
#   '2 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '88094441': ['Alquiler de Piso en calle Joaquín Costa',
#   'El Raval, Barcelona',
#   '1200',
#   '65',
#   '2 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '2019',
#   '',
#   'cocina equipada',
#   'amueblado',
#   '',
#   'calefacción',
#   'con ascensor',
#   'interior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '86811069': ['Alquiler de Piso en C/Joaquín Costa',
#   'El Raval, Barcelona',
#   '1350',
#   '50',
#   '2 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 2',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '86812016': ['Alquiler de Piso en C/Joaquín Costa',
#   'El Raval, Barcelona',
#   '1350',
#   '50',
#   '2 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 4',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95908960': ['Alquiler de Piso en calle del Marquès de Barberà',
#   'El Raval, Barcelona',
#   '1800',
#   '100',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'bajo',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96549170': ['Alquiler de Piso en calle de les Carretes, 85',
#   'El Raval, Barcelona',
#   '900',
#   '45',
#   '1 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 2',
#   '',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96430245': ['Alquiler de Piso en calle de la Riereta',
#   'El Raval, Barcelona',
#   '1300',
#   '55',
#   '2 hab',
#   '1 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '2021',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'bajo',
#   'calefacción',
#   'con ascensor',
#   'interior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95723590': ['Alquiler de Piso en calle de la Reina Amàlia',
#   'El Raval, Barcelona',
#   '1900',
#   '80',
#   '2 hab',
#   '2 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '2021',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   'interior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95723602': ['Alquiler de Piso en calle de la Reina Amàlia',
#   'El Raval, Barcelona',
#   '1400',
#   '75',
#   '1 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '2021',
#   'armarios',
#   '',
#   '',
#   'planta 2',
#   'calefacción',
#   'con ascensor',
#   'interior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '37815387': ['Alquiler de Piso en calle del Marquès de Barberà',
#   'El Raval, Barcelona',
#   '1400',
#   '124',
#   '3 hab',
#   '2 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '1850',
#   '',
#   'cocina sin equipar',
#   'sin amueblar',
#   'planta 1',
#   '',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '90338170': ['Alquiler de Piso en calle del Carme',
#   'El Raval, Barcelona',
#   '2000',
#   '170',
#   '4 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '1900',
#   'armarios',
#   'cocina equipada',
#   'sin amueblar',
#   'bajo',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '87875263': ['Alquiler de Piso en calle de Guàrdia',
#   'El Raval, Barcelona',
#   '1600',
#   '100',
#   '2 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   '',
#   '',
#   'planta 3',
#   'calefacción',
#   '',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '35743786': ['Alquiler de Piso en calle Nou de la Rambla',
#   'El Raval, Barcelona',
#   '1800',
#   '50',
#   '1 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '81244499': ['Alquiler de Piso en calle de les Penedides',
#   'El Raval, Barcelona',
#   '1400',
#   '47',
#   '1 hab',
#   '1 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'calefacción',
#   'con ascensor',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '81453261': ['Alquiler de Piso en calle de les Penedides',
#   'El Raval, Barcelona',
#   '1640',
#   '55',
#   '2 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   '',
#   '',
#   'planta 2',
#   'calefacción',
#   'con ascensor',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96614977': ['Alquiler de Piso en calle del Carme',
#   'El Raval, Barcelona',
#   '1200',
#   '93',
#   '2 hab',
#   '1 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   '',
#   'calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
# ...
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   '',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '34085091': ['Alquiler de Estudio en calle de la cera',
#   'El Raval, Barcelona',
#   '850',
#   '65',
#   'sin habitación',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina sin equipar',
#   'sin amueblar',
#   'planta 3',
#   '',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96179425': ['Alquiler de Piso en Passatge de Bernardí Martorell',
#   'El Raval, Barcelona',
#   '2450',
#   '110',
#   '3 hab',
#   '2 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   '',
#   '',
#   'planta 3',
#   'no dispone de calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96605348': ["Alquiler de Estudio en calle de l'Arc del Teatre, 58",
#   'El Raval, Barcelona',
#   '570',
#   '16',
#   'sin habitación',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'bajo',
#   '',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '81599974': ['Alquiler de Estudio en calle del Príncep de Viana, 3',
#   'El Raval, Barcelona',
#   '750',
#   '35',
#   'sin habitación',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   '',
#   'con ascensor',
#   'interior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96424808': ['Alquiler de Piso en calle Ferlandina',
#   'El Raval, Barcelona',
#   '850',
#   '74',
#   '2 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '1900',
#   '',
#   'cocina equipada',
#   'sin amueblar',
#   '',
#   '',
#   'con ascensor',
#   'interior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '88814065': ["Alquiler de Piso en calle de l'Hospital",
#   'El Raval, Barcelona',
#   '1500',
#   '65',
#   '2 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96180889': ['Alquiler de Estudio en calle de la Junta de Comerç, 20',
#   'El Raval, Barcelona',
#   '1100',
#   '60',
#   'sin habitación',
#   '1 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'bajo',
#   '',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '90807688': ['Alquiler de Piso en calle Guardia',
#   'El Raval, Barcelona',
#   '1900',
#   '90',
#   '2 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '88842459': ['Alquiler de Estudio en calle de Torres i Amat',
#   'El Raval, Barcelona',
#   '1600',
#   '50',
#   'sin habitación',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '1690095': ['Alquiler de Piso en calle Joaquín Costa, 37',
#   'El Raval, Barcelona',
#   '1450',
#   '90',
#   '4 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   'calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95705652': ['Alquiler de Piso en El Raval',
#   'Ciutat Vella, Barcelona',
#   '646',
#   '58',
#   '1 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   '',
#   '',
#   'planta 5',
#   'no dispone de calefacción',
#   'sin ascensor',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '93796398': ["Alquiler de Piso en La Dreta de l'Eixample",
#   'Eixample, Barcelona',
#   '1300',
#   '52',
#   '1 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '1900',
#   '',
#   'cocina equipada',
#   'sin amueblar',
#   'planta 5',
#   'no dispone de calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '92927120': ['Alquiler de Piso en El Raval',
#   'Ciutat Vella, Barcelona',
#   '2300',
#   '116',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '1890',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96609632': ['Alquiler de Piso en calle de la Reina Amàlia',
#   'El Raval, Barcelona',
#   '600',
#   '36',
#   '1 hab',
#   '1 baño',
#   '',
#   'balcón',
#   '',
#   '1900',
#   '',
#   'cocina sin equipar',
#   'sin amueblar',
#   'planta 2',
#   'no dispone de calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '91913093': ['Alquiler de Estudio en rambla del Raval, 14',
#   'El Raval, Barcelona',
#   '790',
#   '30',
#   'sin habitación',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   'calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '88165443': ['Alquiler de Piso en calle de Ferlandina, 67',
#   'El Raval, Barcelona',
#   '1400',
#   '82',
#   '2 hab',
#   '1 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 6',
#   'calefacción',
#   'con ascensor',
#   'interior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '94490194': ['Alquiler de Dúplex en El Raval',
#   'Ciutat Vella, Barcelona',
#   '1100',
#   '40',
#   '1 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '1819',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 4',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '94316853': ['Alquiler de Estudio en calle de Torres i Amat',
#   'El Raval, Barcelona',
#   '800',
#   '55',
#   'sin habitación',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina sin equipar',
#   'sin amueblar',
#   'planta 3',
#   '',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '84539742': ['Alquiler de Piso en calle del Carme, Barcelona',
#   'El Raval, Barcelona',
#   '1200',
#   '95',
#   '5 hab',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   'interior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96372813': ['Alquiler de Piso en calle de la Cera',
#   'El Raval, Barcelona',
#   '850',
#   '60',
#   '2 hab',
#   '2 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '1800',
#   '',
#   'cocina sin equipar',
#   'sin amueblar',
#   'planta 1',
#   'no dispone de calefacción',
#   'sin ascensor',
#   'interior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96322452': ['Alquiler de Estudio en calle de la Riera Alta',
#   'El Raval, Barcelona',
#   '1150',
#   '36',
#   'sin habitación',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '2019',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '799431': ['Alquiler de Piso en calle Tigre',
#   'El Raval, Barcelona',
#   '840',
#   '49',
#   '2 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '1900',
#   '',
#   'cocina equipada',
#   'sin amueblar',
#   'planta 1',
#   '',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95505897': ['Alquiler de Piso en calle de la Riera Alta',
#   'El Raval, Barcelona',
#   '920',
#   '31',
#   '1 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '1819',
#   '',
#   '',
#   '',
#   'planta 3',
#   'no dispone de calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96080002': ['Alquiler de Piso en calle de la Riera Alta',
#   'El Raval, Barcelona',
#   '880',
#   '31',
#   '1 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '1819',
#   '',
#   '',
#   '',
#   'planta 4',
#   'no dispone de calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95874695': ['Alquiler de Piso en rambla NOU DE LA',
#   'El Raval, Barcelona',
#   '900',
#   '76',
#   '2 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '1900',
#   '',
#   'cocina equipada',
#   'sin amueblar',
#   'planta 1',
#   'no dispone de calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '94397000': ['Alquiler de Dúplex en calle de la Riera Alta',
#   'El Raval, Barcelona',
#   '1100',
#   '40',
#   '1 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '1819',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 4',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96197817': ['Alquiler de Estudio en calle dels Tallers',
#   'El Raval, Barcelona',
#   '650',
#   '30',
#   'sin habitación',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '1810',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 2',
#   'no dispone de calefacción',
#   'con ascensor',
#   'interior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95719042': ['Alquiler de Piso en calle de les Carretes',
#   'El Raval, Barcelona',
#   '750',
#   '50',
#   '1 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   'interior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '31654249': ['Alquiler de Estudio en calle de sant pacià, 14',
#   'El Raval, Barcelona',
#   '575',
#   '45',
#   'sin habitación',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'bajo',
#   '',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96481220': ['Alquiler de Estudio en calle de la Reina Amàlia, 9',
#   'El Raval, Barcelona',
#   '850',
#   '55',
#   'sin habitación',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'bajo',
#   '',
#   'sin ascensor',
#   'interior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '83650389': ['Alquiler de Ático en rambla del Raval, 26',
#   'El Raval, Barcelona',
#   '795',
#   '60',
#   '1 hab',
#   '1 baño',
#   'terraza',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 5',
#   'calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96079436': ['Alquiler de Piso en calle de la Cera',
#   'El Raval, Barcelona',
#   '1005',
#   '69',
#   '3 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   '',
#   '',
#   'planta 4',
#   'no dispone de calefacción',
#   '',
#   '',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95930066': ['Alquiler de Piso en El Raval',
#   'Ciutat Vella, Barcelona',
#   '750',
#   '59',
#   '1 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '2010',
#   '',
#   '',
#   '',
#   'planta 3',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95507989': ['Alquiler de Piso en calle de Pelai',
#   "La Dreta de l'Eixample, Barcelona",
#   '1500',
#   '50',
#   '1 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '1900',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 5',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96430655': ['Alquiler de Piso en calle de la Morera, 1',
#   'El Raval, Barcelona',
#   '1050',
#   '52',
#   '1 hab',
#   '2 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   '',
#   '',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96441193': ['Alquiler de Ático en El Raval',
#   'Ciutat Vella, Barcelona',
#   '800',
#   '30',
#   'sin habitación',
#   '1 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina sin equipar',
#   'sin amueblar',
#   'planta 4',
#   '',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '40579547': ['Alquiler de Piso en El Raval',
#   'Ciutat Vella, Barcelona',
#   '830',
#   '60',
#   '2 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 2',
#   '',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96460536': ['Alquiler de Piso en calle del Carme',
#   'El Raval, Barcelona',
#   '1450',
#   '80',
#   '2 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'no dispone de calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '92313882': ['Alquiler de Ático en rambla del Raval, 49',
#   'El Raval, Barcelona',
#   '875',
#   '60',
#   '3 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   '',
#   '',
#   'planta 5',
#   '',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '30630394': ['Alquiler de Piso en calle Arc del Teatre, 21',
#   'El Raval, Barcelona',
#   '2650',
#   '134',
#   '5 hab',
#   '5 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   '',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96694435': ['Alquiler de Piso en calle de la Reina Amàlia',
#   'El Raval, Barcelona',
#   '1000',
#   '52',
#   '2 hab',
#   '2 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '1900',
#   'armarios',
#   '',
#   '',
#   'planta 2',
#   'calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '90576564': ['Alquiler de Piso en El Raval',
#   'Ciutat Vella, Barcelona',
#   '900',
#   '50',
#   '2 hab',
#   '1 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '1856',
#   '',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95598250': ["Alquiler de Piso en calle de l'Hospital",
#   'El Raval, Barcelona',
#   '1200',
#   '153',
#   '4 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '1880',
#   '',
#   '',
#   '',
#   '',
#   'calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95893670': ['Alquiler de Dúplex en calle de Gravina',
#   'El Raval, Barcelona',
#   '2000',
#   '81',
#   '2 hab',
#   '2 baño',
#   '',
#   'balcón',
#   'segunda mano/buen estado',
#   '1890',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 1',
#   'no dispone de calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95866167': ['Alquiler de Piso en calle de la Reina Amàlia',
#   'El Raval, Barcelona',
#   '1600',
#   '80',
#   '2 hab',
#   '2 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '2021',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   'planta 3',
#   'no dispone de calefacción',
#   'con ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96287094': ['Alquiler de Piso en calle de la Junta de Comerç',
#   'El Raval, Barcelona',
#   '950',
#   '70',
#   '2 hab',
#   '1 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '1900',
#   '',
#   '',
#   '',
#   '',
#   'no dispone de calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '95975876': ['Alquiler de Piso en calle de la Junta de Comerç',
#   'El Raval, Barcelona',
#   '1050',
#   '70',
#   '1 hab',
#   '1 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '1900',
#   '',
#   '',
#   '',
#   'bajo',
#   'no dispone de calefacción',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96423108': ['Alquiler de Piso en calle de Vistalegre',
#   'El Raval, Barcelona',
#   '950',
#   '100',
#   '3 hab',
#   '1 baño',
#   '',
#   '',
#   'segunda mano/buen estado',
#   '',
#   'armarios',
#   'cocina equipada',
#   'amueblado',
#   '',
#   '',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)],
#  '96407507': ['Alquiler de Piso en calle de Vistalegre',
#   'El Raval, Barcelona',
#   '950',
#   '100',
#   '3 hab',
#   '1 baño',
#   'terraza',
#   '',
#   'segunda mano/buen estado',
#   '',
#   '',
#   'cocina equipada',
#   'sin amueblar',
#   '',
#   '',
#   'sin ascensor',
#   'exterior',
#   '08001',
#   datetime.date(2022, 2, 9)]}

# %%
df_08001 = df_parse(dic_to_df(data_ids_08001))

# %%
df_08001.to_csv("data_08001.csv",encoding = 'utf-8-sig')

# %%
# cp.remove('08001')
# cp.remove('08028')
# cp

# %%
cp[0:2]
# Out:
# ['08002', '08003']

# %%
for ind, zip_code in enumerate(cp[0:3]):
    id_from_cp = get_ids(headers, zip_code)
    dic_data = obtain_data_from_ids(id_from_cp,headers,cp = zip_code)
    df_data = df_parse(dic_to_df(dic_data))
    df_data.to_csv("data_{}.csv".format(zip_code),encoding = 'utf-8-sig')
