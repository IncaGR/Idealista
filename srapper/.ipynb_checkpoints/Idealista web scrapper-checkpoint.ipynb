# %%
import requests
from bs4 import BeautifulSoup as bs
import time
import random
import json
import matplotlib.pyplot as plt

# %%
url = "https://www.idealista.com/inmueble/95249555/" # pagina con el piso de prueba

# %%
id_inmueble = "95249555"

# %%
r = requests.get(url) # no sirve asi saben que somos bot

# %%
r # response 403 nos detecta como bots
# Out:
# <Response [403]>

# %%
# headers -> Ctrl + shift + i (pagina de desarrollador) -> network Ctrl + f5 -> primera pestaña -> request headers
# desde "accept" ponerlo en dict 
headers = {
"accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
"accept-encoding": "gzip, deflate, br",
"accept-language": "en-GB,en;q=0.9,en-US;q=0.8,ca;q=0.7,es;q=0.6,eo;q=0.5",
"cache-control": "no-cache",
"cookie": '''atuserid=%7B%22name%22%3A%22atuserid%22%2C%22val%22%3A%2268f673fe-430e-424d-9df0-0cd8699a34a7%22%2C%22options%22%3A%7B%22end%22%3A%222023-03-03T18%3A46%3A49.424Z%22%2C%22path%22%3A%22%2F%22%7D%7D; atidvisitor=%7B%22name%22%3A%22atidvisitor%22%2C%22val%22%3A%7B%22vrn%22%3A%22-582065-%22%7D%2C%22options%22%3A%7B%22path%22%3A%22%2F%22%2C%22session%22%3A15724800%2C%22end%22%3A15724800%7D%7D; didomi_token=...; euconsent-v2=CPTmlIAPTmlIAAHABBENB_CoAP_AAAAAAAAAF5wBAAIAAtAC2AvMAAABAaADAAEEQyUAGAAIIhlIAMAAQRDIQAYAAgiGOgAwABBEMJABgACCIYyADAAEEQxUAGAAIIhg.f_gAAAAAAAAA; _gcl_au=1.1.8146483.1643568415; _fbp=fb.1.1643568415299.2070506742; afUserId=58c2a54c-4375-4eb4-baca-6a6e48c65725-p; AF_SYNC=1643568416416; askToSaveAlertPopUp=true; _hjSessionUser_250321=eyJpZCI6ImU0N2FkYjkyLTgyMDMtNWU0Mi1iMTRiLWIzMzQzMDE0NTM0NiIsImNyZWF0ZWQiOjE2NDM1Njg1MjgzMzYsImV4aXN0aW5nIjp0cnVlfQ==; userUUID=6eadbb28-4981-4c13-abda-fd7fadaec832; SESSION=f1f80941eb4fade2~bda569d4-9873-4a74-80a2-5fd0ae1a6c25; contactbda569d4-9873-4a74-80a2-5fd0ae1a6c25="{'email':null,'phone':null,'phonePrefix':null,'friendEmails':null,'name':null,'message':null,'message2Friends':null,'maxNumberContactsAllow':10,'defaultMessage':true}"; cookieSearch-1="/alquiler-viviendas/barcelona/les-corts/les-corts/:1643650811421"; sendbda569d4-9873-4a74-80a2-5fd0ae1a6c25="{'friendsEmail':null,'email':null,'message':null}"; _hjIncludedInSessionSample=1; _hjSession_250321=eyJpZCI6IjYyNTE2ZTJjLWNkNTYtNDRkZS05NmJkLWQ4ZjYxYjQwMGE1NCIsImNyZWF0ZWQiOjE2NDM2NTEzNjU5MTEsImluU2FtcGxlIjp0cnVlfQ==; _hjAbsoluteSessionInProgress=0; _hjCachedUserAttributes=eyJhdHRyaWJ1dGVzIjp7ImlkX3BhZ2VMYW5ndWFnZSI6ImVzIiwiaWRfdXNlclJvbGUiOiIifSwidXNlcklkIjpudWxsfQ==; ABTasty=uid=s43fcyc0hr2z8nkz&fst=1643568412317&pst=1643568412317&cst=1643650069991&ns=2&pvt=35&pvis=13&th=; ABTastySession=mrasn=&sen=12&lp=https%253A%252F%252Fwww.idealista.com%252F; utag_main=v_id:017eac27920f001f94d41f93932f05072002f06a00978$_sn:3$_se:17$_ss:0$_st:1643653573939$dc_visit:2$ses_id:1643650066499%3Bexp-session$_pn:13%3Bexp-session$_prevVtSource:directTraffic%3Bexp-1643653668218$_prevVtCampaignCode:%3Bexp-1643653668218$_prevVtDomainReferrer:%3Bexp-1643653668218$_prevVtSubdomaninReferrer:%3Bexp-1643653668218$_prevVtUrlReferrer:%3Bexp-1643653668218$_prevVtCampaignLinkName:%3Bexp-1643653668218$_prevVtCampaignName:%3Bexp-1643653668218$_prevVtRecommendationId:%3Bexp-1643653668218$_prevCompletePageName:12%3A%3Adetail%3A%3A%3A%3A%3A%3Ahome%3Bexp-1643655375478$_prevLevel2:12%3Bexp-1643655375478$_prevAdId:94476328%3Bexp-1643655375489$_prevAdOriginTypeRecommended:undefined%3Bexp-1643653668228$dc_event:5%3Bexp-session$dc_region:us-east-1%3Bexp-session; cto_bundle=5izo9l9XUkgzNEJIYU9ITGFNWU5xMWp4YWoxNCUyRnFJN2dHbFJTbWRCVlpldHRFbjF4aFFaSmFvWHZvV3B2WCUyRmx1MEhiMUNQbDlUQmlPckkwdW51VTdTZjltc255c0ZjRng0d1c4MXVFVURBdUFXdEYwaSUyQnhtSlowY3oybzE4TkxtY2RVWmR3ZHJvbVJvUko1MmQxT1FJczJvV2clM0QlM0Q; datadome=v475FOZILU7oISIcQM..EhoU-BUZiH-ZFK2rcgXnvpb4HM05afYuAyFXtJCwx2Wz7bUmxBeuhegZikjdshl3ZtuSvzBOApWI_EnGCatwDUdNRGdY_Ox0oK6H5CgXTyT''',
"pragma": "no-cache",
"referer": "https://www.idealista.com/inmueble/95249555/",
"sec-ch-ua": '" Not;A Brand";v="99", "Google Chrome";v="97", "Chromium";v="97"',
"sec-ch-ua-mobile": "?0",
"sec-ch-ua-platform": '"Windows"',
"sec-fetch-dest": "document",
"sec-fetch-mode": "navigate",
"sec-fetch-site": "same-origin",
"sec-fetch-user": "?1",
"upgrade-insecure-requests": "1",
"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36"
    
}

# %%
r = requests.get(url,headers=headers) # añadimos parametro headers

# %%
r # response 200 nos detecta como humanos
# Out:
# <Response [200]>

# %%
soup = bs(r.text,'lxml') # con bs leer en formato texto

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="" data-userauth="false" env="es" lang="es" username="">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>Alquiler de Piso en calle de Caballero, Les Corts, Barcelona — idealista</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="piso de 81 m², Alquiler de Piso en calle de Caballero, Les Corts, Barcelona, barrio Les Corts" name="description"/>
# <meta content="idealista.com" name="author"/>
# <meta content="on" http-equiv="cleartype"/>
# <meta content="no-cache" name="pragma"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="Fri, 01 Jan 1990 00:00:00 GMT" http-equiv="Expires"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/>
# <script defer="" src="https://st1.idealista.com/static/common/js/lib/jquery/jquery-1.10.2.js"></script>
# <script src="https://st1.idealista.com/static/common/release/mavericks/legacy/js/didomi/didomi-consent-lang.js"></script>
# <script src="https://st1.idealista.com/static/common/release/mavericks/legacy/js/didomi/didomi-iab-integration.js"></script>
# <script src="https://st1.idealista.com/static/common/release/mavericks/legacy/js/didomi/didomi-embed.js"></script>
# <script src="https://st1.idealista.com/static/common/release/mavericks/legacy/js/tealium/tealium-wrapper.js?20220131004146"></script>
# <link href="https://st1.idealista.com/favicon.ico?20220131004146" rel="shortcut icon"/>
# <link href="https://st1.idealista.com/static/common/icons/32x32.png?20220131004146" rel="apple-touch-icon" sizes="32x32"/>
# <link href="https://st1.idealista.com/static/common/icons/32x32.png?20220131004146" rel="apple-touch-icon-precomposed"/>
# <link href="https://st1.idealista.com/static/common/icons/57x57.png?20220131004146" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://st1.idealista.com/static/common/icons/57x57.png?20220131004146" rel="apple-touch-icon-precomposed"/>
# <link href="https://st1.idealista.com/static/common/icons/60x60.png?20220131004146" rel="apple-touch-icon"/>
# <link href="https://st1.idealista.com/static/common/icons/60x60.png?20220131004146" rel="apple-touch-icon-precomposed"/>
# <link href="https://st1.idealista.com/static/common/icons/76x76.png?20220131004146" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://st1.idealista.com/static/common/icons/76x76.png?20220131004146" rel="apple-touch-icon-precomposed" sizes="76x76"/>
# <link href="https://st1.idealista.com/static/common/icons/96x96.png?20220131004146" rel="apple-touch-icon" sizes="96x96"/>
# <link href="https://st1.idealista.com/static/common/icons/96x96.png?20220131004146" rel="apple-touch-icon-precomposed"/>
# <link href="https://st1.idealista.com/static/common/icons/120x120.png?20220131004146" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://st1.idealista.com/static/common/icons/120x120.png?20220131004146" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <link href="https://st1.idealista.com/static/common/icons/128x128.png?20220131004146" rel="apple-touch-icon" sizes="128x128"/>
# <link href="https://st1.idealista.com/static/common/icons/128x128.png?20220131004146" rel="apple-touch-icon-precomposed"/>
# <link href="https://st1.idealista.com/static/common/icons/144x144.png?20220131004146" rel="apple-touch-icon" sizes="144x144"/>
# <link href="https://st1.idealista.com/static/common/icons/144x144.png?20220131004146" rel="apple-touch-icon-precomposed"/>
# <link href="https://st1.idealista.com/static/common/icons/152x152.png?20220131004146" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://st1.idealista.com/static/common/icons/152x152.png?20220131004146" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="https://st1.idealista.com/static/common/icons/167x167.png?20220131004146" rel="apple-touch-icon" sizes="167x167"/>
# <link href="https://st1.idealista.com/static/common/icons/167x167.png?20220131004146" rel="apple-touch-icon-precomposed"/>
# <link href="https://st1.idealista.com/static/common/icons/180x180.png?20220131004146" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://st1.idealista.com/static/common/icons/180x180.png?20220131004146" rel="apple-touch-icon-precomposed"/>
# <link href="https://st1.idealista.com/static/common/icons/192x192.png?20220131004146" rel="apple-touch-icon" sizes="192x192"/>
# <link href="https://st1.idealista.com/static/common/icons/192x192.png?20220131004146" rel="apple-touch-icon-precomposed"/>
# <link href="https://st1.idealista.com/static/common/icons/195x195.png?20220131004146" rel="apple-touch-icon" sizes="195x195"/>
# <link href="https://st1.idealista.com/static/common/icons/195x195.png?20220131004146" rel="apple-touch-icon-precomposed"/>
# <link href="https://st1.idealista.com/static/common/icons/196x196.png?20220131004146" rel="apple-touch-icon" sizes="196x196"/>
# <link href="https://st1.idealista.com/static/common/icons/196x196.png?20220131004146" rel="apple-touch-icon-precomposed"/>
# <script async="" charset="utf-8" data-vendor="c:abtasty-LLkECCj8" src="//try.abtasty.com/ba99abce363c777e429f2eef6f87c927.js" type="didomi/javascript"></script>
# <link as="style" href="https://st1.idealista.com/static/common/release/detail/detail.css?20220131004146" rel="preload"/>
# <link href="https://st1.idealista.com/static/common/release/detail/detail.css?20220131004146" rel="stylesheet" type="text/css"/>
# <link href="https://www.idealista.com/inmueble/95249555/" rel="canonical"/>
# <meta content="NOODP,INDEX, FOLLOW" name="ROBOTS"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, minimum-scale=1.0" name="viewport"/>
# <meta content="https://img3.idealista.com/blur/WEB_DETAIL-M-L/0/id.pro.es.image.master/31/f9/ba/951484558.jpg" property="og:image"/>
# <meta content="1500" property="og:image:width"/>
# <meta content="1125" property="og:image:height"/>
# <link href="https://www.idealista.com/ca/inmueble/95249555/" hreflang="ca" rel="alternate"/><link href="https://www.idealista.com/en/inmueble/95249555/" hreflang="en" rel="alternate"/><link href="https://www.idealista.com/fr/inmueble/95249555/" hreflang="fr" rel="alternate"/><link href="https://www.idealista.com/de/inmueble/95249555/" hreflang="de" rel="alternate"/><link href="https://www.idealista.com/it/inmueble/95249555/" hreflang="it" rel="alternate"/><link href="https://www.idealista.com/pt/inmueble/95249555/" hreflang="pt" rel="alternate"/><link href="https://www.idealista.com/da/inmueble/95249555/" hreflang="da" rel="alternate"/><link href="https://www.idealista.com/fi/inmueble/95249555/" hreflang="fi" rel="alternate"/><link href="https://www.idealista.com/no/inmueble/95249555/" hreflang="no" rel="alternate"/><link href="https://www.idealista.com/nl/inmueble/95249555/" hreflang="nl" rel="alternate"/><link href="https://www.idealista.com/pl/inmueble/95249555/" hreflang="pl" rel="alternate"/><link href="https://www.idealista.com/ro/inmueble/95249555/" hreflang="ro" rel="alternate"/><link href="https://www.idealista.com/ru/inmueble/95249555/" hreflang="ru" rel="alternate"/><link href="https://www.idealista.com/sv/inmueble/95249555/" hreflang="sv" rel="alternate"/><link href="https://www.idealista.com/el/inmueble/95249555/" hreflang="el" rel="alternate"/><link href="https://www.idealista.com/zh/inmueble/95249555/" hreflang="zh" rel="alternate"/>
# <link as="font" crossorigin="" href="https://st1.idealista.com/static/common/release/modules/resources/fonts/bernino-regular.woff?v1" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="" href="https://st1.idealista.com/static/common/release/modules/resources/fonts/bernino-bold.woff?v1" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="" href="https://st1.idealista.com/static/common/release/modules/resources/fonts/bernino-semibold.woff?v1" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="" href="https://st1.idealista.com/static/common/release/modules/resources/fonts/idealista-regular.woff?v69" rel="preload" type="font/woff"/>
# <script>
# 			var isCloseOutsideModalDisableMobileToggle = true;
# 		</script>
# </head>
# <body class="" id="">
# <script>
# 	var utag_data = {"page":{"section":"portal","subSection":"detail","name":"home","language":"es","category":"detail","subCategory":"","subSubCategory":"","template":"","position":""},"user":{"status":"2"},"response":{"statusCode":"200","loadBalancer":"web"},"ad":{"id":"95249555","operation":"2","typology":"1","address":{"municipalityId":"0-EU-ES-08-13-001-019","provinceId":"0-EU-ES-08","locationId":"0-EU-ES-08-13-001-019-04-001","locationLevel":"8"},"builtType":"3","energyCertification":{"type":"e","suffix":"spainDefault"},"price":"890","characteristics":{"roomNumber":"3","bathNumber":"2","hasLift":"1","hasParking":"0","hasGarden":"0","hasSwimmingPool":"0","hasTerrace":"1","constructedArea":"81"},"condition":{"isNewDevelopment":"0","isNeedsRenovating":"0","isGoodCondition":"1"},"media":{"photoNumber":"27","videoNumber":"0","hasFloorPlan":"0","has3Dtour":"0","hasHomeStaging":"0"},"owner":{"type":"2","commercialId":"","commercialName":"diagonalcasa","contactPreference":"1","chatIsActive":"0"},"origin":"4","isRecommended":"0","hasRecommended":"1","numberRecommended":"","originTypeRecommended":"","typeRecommended":"","isAuction":"0","recommendationId":"","vtRecommendationAdId":"","vtRecommendationId":""},"search":{"operation":"2","typology":"1","geo":{"type":"OFFICIAL_ZONE","locationId":"0-EU-ES-08-13-001-019-04-001","locationLevel":"8"},"orderBy":"relevance-desc"},"correlation":{"id":"91ea369f-782a-4b91-b4e2-fc09a019dbe5","session":"6eadbb28-4981-4c13-abda-fd7fadaec832"},"event":{"id":"","type":"","name":"","action":"","role":"","user_role":"","channel":"","origin":"","outcome":"","hash":"","markup":{"xtPage":"","name":"","category":"","subCategory":"","subSubCategory":""},"productType":"","agencyNames":[],"transactionId":""},"didomiVendorsConsent":"","post":{"id":"15ecf728-612e-4cc6-b9c3-7d83a9eb3eb7","time":"1643706344656"}};
# 	var dataLayerContext = utag_data;
#
#         window.utag_cfg_ovrd = { noview: true };
#
#     window.utag_data = utag_data;
# </script>
# <script>
#     (function(a,b,c,d){
#         a='//tags.tiqcdn.com/utag/idealista/es-portal/prod/utag.js';
#         b=document;c='script';d=b.createElement(c);d.onload=function () { window.idealistaUtag && window.idealistaUtag.init() };d.src=a;d.type='text/java'+c;d.defer=true;
#         a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a);
#     })();
# </script>
# <script>
#     var didomiActive = true;
#     if(!true) {
#         function onInitIdealistaUtag() {
#             window.utag.view(window.utag_data);
#         }
#
#         if (window.idealistaUtag) {
#             window.idealistaUtag.onInit(onInitIdealistaUtag);
#         }
#
#     }
#     if(true && !didomiActive){
#         window.utag_cfg_ovrd = { noview: true };
#     }
# </script>
# <header class="help-center ide-header" id="main-header">
# <div class="col-ide-lg-12 col-ide-xl-12 content">
# <figure class="logo-container">
# <a class="id-logo" href="/"> <img alt="idealista" src="https://st1.idealista.com/static/common/img/idealista.svg" title="idealista"/></a>
# </figure>
# <nav>
# <div class="lang-selector lang-responsive">
# <span class="lang-selector--lang-selected icon-arrow-dropdown">
# <span class="flag lang-es"></span>
# <span class="lang-text">Español</span>
# </span>
# <ul class="lang-selector--lang-options" data-url-attribute="/user/update-user-language" data-user-authenticated="false">
# <li>
# <a data-markup="cambio::idioma::cabecera::ca" href="/ca/inmueble/95249555/" id="idioma-ca" rel="nofollow" value="ca">
# <span>
# <span class="flag lang-ca"></span>Català
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::en" href="/en/inmueble/95249555/" id="idioma-en" rel="nofollow" value="en">
# <span>
# <span class="flag lang-en"></span>English
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::fr" href="/fr/inmueble/95249555/" id="idioma-fr" rel="nofollow" value="fr">
# <span>
# <span class="flag lang-fr"></span>Français
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::de" href="/de/inmueble/95249555/" id="idioma-de" rel="nofollow" value="de">
# <span>
# <span class="flag lang-de"></span>Deutsch
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::it" href="/it/inmueble/95249555/" id="idioma-it" rel="nofollow" value="it">
# <span>
# <span class="flag lang-it"></span>Italiano
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::pt" href="/pt/inmueble/95249555/" id="idioma-pt" rel="nofollow" value="pt">
# <span>
# <span class="flag lang-pt"></span>Português
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::da" href="/da/inmueble/95249555/" id="idioma-da" rel="nofollow" value="da">
# <span>
# <span class="flag lang-da"></span>Dansk
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::fi" href="/fi/inmueble/95249555/" id="idioma-fi" rel="nofollow" value="fi">
# <span>
# <span class="flag lang-fi"></span>Suomi
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::no" href="/no/inmueble/95249555/" id="idioma-no" rel="nofollow" value="no">
# <span>
# <span class="flag lang-no"></span>Norsk
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::nl" href="/nl/inmueble/95249555/" id="idioma-nl" rel="nofollow" value="nl">
# <span>
# <span class="flag lang-nl"></span>Nederlands
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::pl" href="/pl/inmueble/95249555/" id="idioma-pl" rel="nofollow" value="pl">
# <span>
# <span class="flag lang-pl"></span>Polski
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::ro" href="/ro/inmueble/95249555/" id="idioma-ro" rel="nofollow" value="ro">
# <span>
# <span class="flag lang-ro"></span>Română
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::ru" href="/ru/inmueble/95249555/" id="idioma-ru" rel="nofollow" value="ru">
# <span>
# <span class="flag lang-ru"></span>Русский
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::sv" href="/sv/inmueble/95249555/" id="idioma-sv" rel="nofollow" value="sv">
# <span>
# <span class="flag lang-sv"></span>Svenska
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::el" href="/el/inmueble/95249555/" id="idioma-el" rel="nofollow" value="el">
# <span>
# <span class="flag lang-el"></span>Ελληνικά
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::zh" href="/zh/inmueble/95249555/" id="idioma-zh" rel="nofollow" value="zh">
# <span>
# <span class="flag lang-zh"></span>中文
# </span>
# </a>
# </li>
# <li class="separator">
# <a data-markup="cambio::pais::cabecera::it" href="https://www.idealista.it/es/" title="">idealista.it</a>
# </li>
# <li>
# <a data-markup="cambio::pais::cabecera::pt" href="https://www.idealista.pt/es/" title="">idealista.pt</a>
# </li>
# </ul>
# </div>
# <ul class="no-logged-user-menu ide-main-menu" id="no-login-user-bar">
# <li class="ide-main-menu__adv-free" id="put-adv-free">
# <a data-markup="header-new-advert" href="/info/publicar-anuncio">
# <span class="icon-pin">
# Pon tu anuncio gratis
# </span>
# </a>
# </li>
# <li id="your-account">
# <a class="icon-user-no-logged" data-markup="header-login" href="/login" rel="nofollow">
# <span class="icon-user-no-logged-text">Iniciar sesión</span>
# <span class="icon-user-no-logged-text-extrasmall-devices">Acceso</span>
# </a>
# </li>
# </ul>
# </nav>
# </div>
# </header>
# <div id="wrapper">
# <div data-islogged="false" id="main">
# <div class="container">
# <div class="detail-pagination" id="pager">
# <div class="content detail-first-picture">
# <nav class="detail-pagination--back">
# <a class="btn nav back icon-arrow-double-left" href="/alquiler-viviendas/barcelona/les-corts/les-corts/" title="Viviendas en Les Corts">
# Viviendas en Les Corts
# </a>
# </nav>
# <p class="detail-pagination--count">
# </p>
# <nav class="detail-pagination--prev-next">
# </nav>
# </div>
# </div>
# <main class="detail-container">
# <picture class="main-image main-image-desktop horizontal-img false-panoramic image-loaded">
# <div class="main-image_first" data-relative-position="0" position="0">
# <img alt="Imagen Estancia de piso en calle de Caballero, Les Corts, Barcelona" class="image-focus show image-focus show" data-orientation="horizontal" src="https://img3.idealista.com/blur/WEB_DETAIL_TOP-L-L/0/id.pro.es.image.master/31/f9/ba/951484558.jpg" title="Imagen Estancia de piso en calle de Caballero, Les Corts, Barcelona"/>
# </div>
# </picture>
# <section class="main-image main-image-device">
# <div class="swipe-mask-wrapper">
# <div class="swipe-mask galleryBoost">
# <picture class="swipe-image">
# <img alt="Imagen Estancia de piso en calle de Caballero, Les Corts, Barcelona" src="https://img3.idealista.com/blur/WEB_DETAIL_TOP-L-L/0/id.pro.es.image.master/31/f9/ba/951484558.jpg" title="Imagen Estancia de piso en calle de Caballero, Les Corts, Barcelona"/>
# </picture>
# </div>
# </div>
# </section>
# <aside class="side-content" id="side-content">
# <div class="module-contact-container" id="module-contact-container">
# <section class="module-contact highlight-content" contact-modal-type="detail">
# <input name="typology" type="hidden" value="1"/>
# <div class="module-contact--border">
# <div class="feedback-container-unblock"></div>
# <h3 class="module-contact_title h3-simulated">
# <strong>Pregunta al anunciante</strong>
# </h3>
# <div class="advertiser-info">
# <div class="advertiser-info__text advertiser-info__gallery">
# <div></div>
# <p class="advertiser-name">
# Diagonalcasa
# </p>
# <div class="shortAdDescription">
# <p class="ellipsis">Alquiler de Piso en calle de Caballero</p>
# </div>
# </div>
# </div>
# <div class="ide-box-contact feedback-save-search feedback-container d-none"></div>
# <div class="module-contact_form">
# <form action="" class="form contact" data-service-error="¡Vaya! No hemos podido enviar tu mensaje ¡Prueba otra vez!" novalidate="">
# <div class="module-contact_feedback">
# <div class="feedback success icon-sent-ok">
# <span class="feedback_message">
# Has contactado
# </span>
# <span class="contacted-time">
# </span>
# </div>
# </div>
# <div class="advertiser-comment-container">
# <div class="advertiser-comment item-form no-margin">
# <label>
# <p class="module-contact_contacted-title">Tu mensaje fue</p>
# <textarea class="module-contact_textarea" data-message-required="Muestra tu interés escribiendo un mensaje" data-validation="required" name="contact-message" placeholder="¿Alguna duda? ¿Quieres visitar el inmueble? ¡Pregunta al anunciante!">Hola, me interesa este piso y me gustaría hacer una visita.
# Un saludo</textarea>
# <ul class="last-contact-messages"></ul>
# </label>
# </div>
# </div>
# <div class="collapsed-form">
# <div class="item-form">
# <div>
# <label>
# <input name="email2" type="hidden"/>
# <span class="email-label">Tu email</span>
# <input autocomplete="email" class="js-email-field" data-contact-data-error="Indica un email o teléfono para que te puedan contestar ;-)" data-message-email="Revisa el formato de tu email" data-required-group="contact-data" data-validation="email" name="contact-email" type="email" value=""/>
# </label>
# </div>
# </div>
# <div class="item-form half-items clearfix">
# <div>
# <label>
# <span class="phone-label">Tu teléfono</span>
# <input autocomplete="tel" class="js-phone-field" data-message-phone="Revisa tu teléfono" data-required-group="contact-data" data-validation="phone" name="contact-phone" type="tel" value=""/>
# </label>
# </div>
# <div>
# <label>
# <span class="name-label">Tu nombre</span>
# <input autocomplete="name" data-message-contact_name="Esto no parece un nombre" data-message-required="Indica tu nombre " data-validation="contact_name" name="contact-name" type="text" value=""/>
# </label>
# </div>
# </div>
# <div class="general-errors-container feedback full-width warning icon-feedbk-alert d-none"></div>
# <div class="service-error-container feedback full-width error icon-feedbk-ko d-none"></div>
# <div class="captcha-miniFields d-none" data-service-prefix="">
# <div class="captcha">
# <div class="captcha-img">
# </div>
# </div>
# <div class="item-form half-items clearfix">
# <label>
# <span>Escribe los números y letras que ves arriba</span>
# <div>
# <input autocapitalize="none" autocorrect="off" class="_captcha" name="contact-captcha" type="text"/>
# </div>
# </label>
# <p><a class="captcha-reload" href="#">¿No entiendes lo que pone?</a></p>
# </div>
# </div>
# <div class="item-form privacy-policy-container" id="privacy-policy-detail">
# <div>
# <label class="input-checkbox" data-error-name="privacy-policy-checkbox" data-message-checkbox="Para contactar debes aceptar la política de privacidad" data-validation="checkbox">
# <input name="privacy-policy-checkbox" type="checkbox"/>
# <span>
# <span>
# Aceptar
# <a href="https://www.idealista.com/ayuda/articulos/politica-de-privacidad/" target="_blank">política de privacidad</a>
# </span>
# </span>
# </label>
# </div>
# </div>
# <div class="item-form recommendations-container" id="recommendations-detail">
# <div>
# <label class="input-checkbox" data-error-name="recommendations-checkbox">
# <input data-markup-recommendations="detalle::conversiones::form_contacto::recomendations-" name="recommendations-checkbox" type="checkbox"/>
# <span>
# <span>
# Recibir inmuebles de idealista similares a este
# </span>
# </span>
# </label>
# </div>
# </div>
# <input name="adId" type="hidden" value="95249555"/>
# <input name="operationId" type="hidden" value="2"/>
# <input id="contact-type" name="type" type="hidden" value="2"/>
# </div>
# <div class="d-none">
# <input name="contact-mail" type="text" value=""/>
# </div>
# <div>
# <input class="btn action txt-bold txt-big desktop" data-contacted="Contactar de nuevo" type="submit" value="Contactar"/>
# <input class="btn action txt-bold txt-big no-desktop" data-contacted="Enviar de nuevo" type="submit" value="Enviar"/>
# </div>
# </form>
# </div>
# <input name="adId" type="hidden" value="95249555"/>
# <div class="ide-box-contact module-contact-gray contact-data-container">
# <h2 class="txt-big txt-bold mb-small">
# Anunciante
# </h2>
# <div class="contact-phones" id="contact-phones-container">
# <div>
# <div class="phone last-phone">
# <p class="txt-bold _browserPhone icon-phone">932 994 519</p>
# </div>
# </div>
# </div>
# <div class="professional-name">
# <div class="name">
# Profesional
# </div>
# <span>
# Diagonalcasa
# <input name="user-name" type="hidden" value="Diagonalcasa "/>
# </span>
# <input name="professional" type="hidden"/>
# </div>
# <div class="ad-reference-container">
# <div class="ref-help">
# Referencia del anuncio
# </div>
# <p class="txt-ref">
# Di__00164
# </p>
# </div>
# </div>
# <div class="ide-box-contact module-contact-gray about-container">
# <div class="about-advertiser">
# <div class="advertiser-logo">
# <a href="/pro/diagonalcasa/">
# <img alt="DIAGONALcasa" data-ondemand-img="https://st3.idealista.com/06/7f/6d/diagonalcasa.gif" height="60" src="https://st3.idealista.com/06/7f/6d/diagonalcasa.gif" width="125"/>
# </a>
# </div>
# </div>
# <div class="advertiser-name-container">
# <a class="about-advertiser-name" href="/pro/diagonalcasa/" title="DIAGONALcasa">
# DIAGONALcasa
# </a>
# <span>barcelona</span>
# </div>
# </div>
# </div>
# </section>
# <div id="suggestions-ads-desktop"></div>
# </div>
# </aside>
# <nav class="sticky-contact-detail" id="sticky-contact">
# <div class="sticky-contact-user col-ide-xs-6 col-ide-sm-4 two-buttons">
# <div class="sticky-contact-user-info">
# <div class="name">
# Profesional
# </div>
# <span>
# <p class="about-advertiser-name">
# Diagonalcasa
# </p>
# </span>
# </div>
# </div>
# <div class="contact-buttons col-ide-xs-12 col-ide-sm-8 two-buttons">
# <a class="_mobilePhone phone-number icon-phone btn action col-ide-xs-6 col-ide-sm-6" href="tel:+34 932 994 519" target="_blank">
# <span class="phone-btn-number">932 994 519</span>
# <span class="phone-btn-txt">Llamar</span>
# </a>
# <button class="contact-fake email-btn icon-chat btn action col-ide-xs-6 col-ide-sm-6" data-role="">
# <span>Contactar</span>
# </button>
# </div>
# </nav>
# <section class="detail-info ide-box-detail-first-picture ide-box-detail--reset overlay-box">
# <div class="fake-anchors corevitals-fixed-height"></div>
# <nav class="sticky-bar-detail" id="fixed-toolbar">
# <div class="content clearfix col-ide-lg-12 col-ide-xl-12">
# <a class="nav back icon-arrow-double-left" href="/alquiler-viviendas/barcelona/les-corts/les-corts/" title="Viviendas en Les Corts"></a>
# <div class="main-info">
# <h2 class="txt-body">
# <span>Alquiler de Piso en calle de Caballero</span>
# </h2>
# <strong class="typology">
# piso
# </strong>
# <p class="info-data txt-big">
# <span class="price-container">
# <strong class="price">890 €/mes</strong>
# </span>
# <span>
# <span>81</span>
# m²
# </span>
# <span>
# <span>3</span>
# hab.
# </span>
# <span>
# <span>Planta 3ª</span>
# con ascensor
# </span>
# </p>
# </div>
# <div class="links">
# <button class="favorite-btn btn regular" data-markup="favourite-toolbar" data-markup-add="favourite-toolbar" data-markup-remove="remove-favourite-toolbar" data-role="add" data-text-add='Guardar&lt;span class="hide-txt"&gt; favorito&lt;/span&gt;' data-text-remove="Favorito"></button>
# <i class="icon-heart" role="image"></i>
# <span>Guardar<span class="hide-txt"> favorito</span></span>
# <button class="discard-btn icon-delete" data-markup="discard-toolbar" data-markup-add="discard-toolbar" data-markup-remove="recover-toolbar" data-role="add" data-text-add="Descartar" data-text-remove="Recuperar"></button>
# <span>Descartar</span>
# </div>
# </div>
# </nav>
# <div class="main-info__title">
# <h1 class="">
# <span class="main-info__title-main">Alquiler de Piso en calle de Caballero</span>
# </h1>
# <span class="main-info__title-block">
# <span class="main-info__title-minor">Les Corts, Barcelona</span>
# <a class="main-info__title-map icon-location showMap" data-markup-map="detalle::map::top" href="#"><span>Ver mapa</span></a>
# </span>
# </div>
# <div class="info-data">
# <span class="info-data-price"><span class="txt-bold">890</span> €/mes</span>
# </div>
# <div class="info-features">
# <span>
# <span>81</span>
# m²
# </span>
# <span>
# <span>3</span>
# hab.
# </span>
# <span>
# <span>Planta 3ª</span>
# con ascensor
# </span>
# <span class="info-features-tags">
# </span>
# </div>
# <div class="links-detail-info" id="links">
# <a class="favorite-btn" data-markup="favourite" data-markup-add="favourite" data-markup-remove="remove-favourite" data-role="add" data-text-add='Guardar&lt;span class="hide-txt"&gt; favorito&lt;/span&gt;' data-text-remove="Favorito" href="#">
# <i class="icon-heart" role="image"></i>
# <span>Guardar<span class="hide-txt"> favorito</span></span>
# </a>
# <a class="discard-btn icon-delete" data-markup="discard" data-markup-add="discard" data-markup-remove="recover" data-role="add" data-text-add="Descartar" data-text-remove="Recuperar" href="#">
# <span>Descartar</span>
# </a>
# <a class="icon-share" href="#" id="share-friend-link" title="Compartir">
# <span>Compartir</span>
# </a>
# </div>
# <div class="comment-wrapper" id="comment-wrapper">
# <span class="print-title">Nota personal</span>
# <div class="text-wrapper">
# <span class="comment-text" id="comment-text"></span>
# <a class="edit-title-mobile">Editar</a>
# <a class="edit-title">Editar nota</a>
# </div>
# <div class="textarea-wrapper">
# <span class="icon-note"></span>
# <textarea class="comment-textarea" data-chars-counter="1000" id="comment-textarea" maxlength="1000" placeholder="Escribe una nota personal (sólo tú podrás verla)" spellcheck="false"></textarea>
# </div>
# </div>
# <div class="commentsContainer" data-url="/ajax/comment.ajax">
# <h3 class="comments-h3">Comentario del anunciante</h3>
# <div class="select-comment-lang">
# Disponible en:
# <a class="current" data-lang="es" href="#">Español</a>
# <a class="optionalLanguage" data-lang="ca" href="#" style="display:none">Català</a>
# <a data-lang="en" href="#">English</a>
# <a class="optionalLanguage" data-lang="fr" href="#" style="display:none">Français</a>
# <a class="optionalLanguage" data-lang="de" href="#" style="display:none">Deutsch</a>
# <a class="optionalLanguage" data-lang="it" href="#" style="display:none">Italiano</a>
# <a class="optionalLanguage" data-lang="pt" href="#" style="display:none">Português</a>
# <a class="optionalLanguage" data-lang="da" href="#" style="display:none">Dansk</a>
# <a class="optionalLanguage" data-lang="fi" href="#" style="display:none">Suomi</a>
# <a class="optionalLanguage" data-lang="no" href="#" style="display:none">Norsk</a>
# <a class="optionalLanguage" data-lang="nl" href="#" style="display:none">Nederlands</a>
# <a class="optionalLanguage" data-lang="pl" href="#" style="display:none">Polski</a>
# <a class="optionalLanguage" data-lang="ro" href="#" style="display:none">Română</a>
# <a class="optionalLanguage" data-lang="ru" href="#" style="display:none">русский</a>
# <a class="optionalLanguage" data-lang="sv" href="#" style="display:none">Svenska</a>
# <a class="optionalLanguage" data-lang="el" href="#" style="display:none">Ελληνικά</a>
# <a class="optionalLanguage" data-lang="zh" href="#" style="display:none">中文</a>
# <nav class="other-comments-lang">
# <span>
# <span>Otros idiomas</span>
# <i class="icon-arrow-dropdown"></i>
# </span>
# <ul>
# <li class="selectorLanguage" data-lang="ca">
# <a class="selectorLanguage" data-lang="ca" href="#">Català</a>
# </li>
# <li class="selectorLanguage" data-lang="fr">
# <a class="selectorLanguage" data-lang="fr" href="#">Français</a>
# </li>
# <li class="selectorLanguage" data-lang="de">
# <a class="selectorLanguage" data-lang="de" href="#">Deutsch</a>
# </li>
# <li class="selectorLanguage" data-lang="it">
# <a class="selectorLanguage" data-lang="it" href="#">Italiano</a>
# </li>
# <li class="selectorLanguage" data-lang="pt">
# <a class="selectorLanguage" data-lang="pt" href="#">Português</a>
# </li>
# <li class="selectorLanguage" data-lang="da">
# <a class="selectorLanguage" data-lang="da" href="#">Dansk</a>
# </li>
# <li class="selectorLanguage" data-lang="fi">
# <a class="selectorLanguage" data-lang="fi" href="#">Suomi</a>
# </li>
# <li class="selectorLanguage" data-lang="no">
# <a class="selectorLanguage" data-lang="no" href="#">Norsk</a>
# </li>
# <li class="selectorLanguage" data-lang="nl">
# <a class="selectorLanguage" data-lang="nl" href="#">Nederlands</a>
# </li>
# <li class="selectorLanguage" data-lang="pl">
# <a class="selectorLanguage" data-lang="pl" href="#">Polski</a>
# </li>
# <li class="selectorLanguage" data-lang="ro">
# <a class="selectorLanguage" data-lang="ro" href="#">Română</a>
# </li>
# <li class="selectorLanguage" data-lang="ru">
# <a class="selectorLanguage" data-lang="ru" href="#">русский</a>
# </li>
# <li class="selectorLanguage" data-lang="sv">
# <a class="selectorLanguage" data-lang="sv" href="#">Svenska</a>
# </li>
# <li class="selectorLanguage" data-lang="el">
# <a class="selectorLanguage" data-lang="el" href="#">Ελληνικά</a>
# </li>
# <li class="selectorLanguage" data-lang="zh">
# <a class="selectorLanguage" data-lang="zh" href="#">中文</a>
# </li>
# </ul>
# </nav>
# </div>
# <div class="comment">
# <div class="adCommentsLanguage expandable is-expandable" data-compressed-max-length="1650">
# <p>
# Amplio salón comedor con salida a terraza.<br/> 3 habitaciones luminosas (2 dobles, 1 individual amplia) <br/> 1 baño y 1 aseo, .<br/> Cocina independiente.<br/> Casi sin muebles <br/> Ascensor<br/> Zona tranquila, muy bien comunicada, todos los servicios. <br/> Índice Medio de precios de alquiler 14,83 €/m2.
# </p>
# </div>
# </div>
# <div class="spinnerTranslations" style="display: none">
# <div class="googleTranslateLogo">
# <img loading="lazy" src="https://st1.idealista.com/static/common/release/detail/resources/img/loading.gif"/>
# </div>
# </div>
# <div class="spinnerTranslationsMobile" style="display: none">
# <div class="googleTranslateLogo">
# <img loading="lazy" src="https://st1.idealista.com/static/common/release/detail/resources/img/loading-mobile.gif"/>
# </div>
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="es" style="display: none">
# Lo sentimos, no es posible traducir el comentario en estos momentos. Prueba de nuevo más tarde.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="ca" style="display: none">
# Ho sentim, no és possible traduir el comentari en aquests moments. Prova de nou més tard.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="en" style="display: none">
# Sorry, we can't translate this description right now. Please try again later.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="fr" style="display: none">
# Nous sommes désolés, nous ne pouvons pas traduire de commentaire pour l'instant. Veuillez réessayer plus tard.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="de" style="display: none">
# Leider kann die Beschreibung im Augenblick nicht übersetzt werden. Bitte versuchen Sie es später noch einmal.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="it" style="display: none">
# Ci dispiace, al momento non è possibile tradurre il commento. Riprova più tardi.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="pt" style="display: none">
# Lamentamos, não é possível traduzir o comentário neste momento. Volta a tentar mais tarde.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="da" style="display: none">
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="fi" style="display: none">
# Kommenttia ei valitettavasti voida tällä hetkellä kääntää. Yritä myöhemmin uudelleen.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="no" style="display: none">
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="nl" style="display: none">
# Sorry, het is niet mogelijk om de reactie op dit moment te vertalen. Probeer het later opnieuw.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="pl" style="display: none">
# Niestety, obecnie nie można przetłumaczyć tego komentarza. Spróbuj ponownie później.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="ro" style="display: none">
# Ne pare rău, pentru moment, nu este posibilă traducerea comentariului. Încearcă din nou mai târziu.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="ru" style="display: none">
# К сожалению, перевод комментария в данный момент невозможен. Попробуйте еще раз позже.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="sv" style="display: none">
# Vi ber om ursäkt, det är inte möjligt att översätta den här kommentaren just nu. Försök igen senare.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="el" style="display: none">
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="zh" style="display: none">
# </div>
# </div>
# <section class="details-box" id="details">
# <div class="details-property">
# <div class="details-property-feature-one">
# <h3 class="details-property-h3">Características básicas</h3>
# <div class="details-property_features">
# <ul>
# <li>81 m² construidos, 70 m² útiles</li>
# <li>3 habitaciones</li>
# <li>2 baños</li>
# <li>Terraza</li>
# <li>Segunda mano/buen estado</li>
# <li>Armarios empotrados</li>
# <li>Orientación sur</li>
# <li>Construido en 1966</li>
# <li>No dispone de calefacción</li>
# </ul>
# </div>
# <h3 class="details-property-h3">Edificio</h3>
# <div class="details-property_features">
# <ul>
# <li>Planta 3ª</li>
# <li>con ascensor</li>
# </ul>
# </div>
# </div>
# <div class="details-property-feature-two">
# <h3 class="details-property-h3">Certificado energético</h3>
# <div class="details-property_features">
# <ul>
# <li>
# <span>Consumo: </span>
# <span class="icon-energy-c-e" title="e">130 kWh/m² año</span>
# </li>
# <div class="energy-certificate-dropdown">
# <a class="energy-certificate-open-link" data-markup="A|ceeLabelShow" href="">Ver etiqueta de calificación energética</a>
# <a class="energy-certificate-close-link" data-markup="A|ceeLabelHide" href="">Ocultar etiqueta</a>
# <figure class="energy-certificate-img-container">
# <span class="energy-certificate-img-ticket-left left-e" data-value-left-cee="130.0"></span>
# <span class="energy-certificate-img-ticket-right right-" data-value-right-cee=""></span>
# <img alt="idealista CEE" class="energy-certificate-img" src="https://st1.idealista.com/static/common/release/detail/resources/img/cee/es.svg?20220131004146"/>
# </figure>
# </div>
# </ul>
# </div>
# </div>
# <div class="details-property-feature-three">
# </div>
# </div>
# </section>
# <section class="details-box date-update-block">
# <span class="icon-feedbk-info"></span>
# <p class="date-update-text">Anuncio actualizado hace 15 horas</p>
# </section>
# </section>
# <div class="multimedia-content" id="premium-multimedia-container">
# <div id="homestaging" role="img"></div>
# <div class="rs-gallery" id="gallery"></div>
# </div>
# <div class="multimedia-content" id="multimedia-container">
# <div class="images-slider" id="main-multimedia">
# </div>
# </div>
# <section class="mortgages-content" id="mortgages">
# <div class="ide-box-detail overlay-box" id="helpus-improve">
# <h3 class="ide-box-detail-h3 icon-flag">
# ¿Hay algún error en este anuncio?
# </h3>
# <p class="helpus-improve_txt">
# Infórmanos para corregirlo y ayudar a otras personas.
# </p>
# <a class="helpus-improve_notify" data-title="Cuéntanos qué error has visto" data-xiti-page="detalle::conversiones::form-reportar-error" data-xiti-shared-n2="true" href="#">
# Cuéntanos qué error has visto
# </a>
# </div>
# <div class="ide-box-detail overlay-box">
# <div class="toggle-price">
# <article class="price-feature clearfix">
# <h2 class="txt-medium txt-bold">Precio</h2>
# <section class="price-features__container">
# <p class="flex-feature">
# <span class="flex-feature-details">Precio del inmueble:</span>
# <strong class="flex-feature-details">890 €/mes</strong>
# </p>
# <p class="flex-feature squaredmeterprice">
# <span class="flex-feature-details">Precio por m²:</span>
# <span class="flex-feature-details">10,99 €/m²</span>
# </p>
# <div>
# <p>
# <a class="counter-offer" data-xiti-page="detalle::conversiones::form_contraoferta" data-xiti-shared-n2="true" href="#" title="Hacer una contraoferta">
# Hacer una contraoferta
# </a>
# </p>
# <p>
# <a class="favorite-btn price-feature-link" data-role="add" data-targetid="13" data-text-add="Recibir aviso si baja de precio" data-text-remove="¡Oído cocina! te avisaremos si baja de precio" data-xiti-click="detalle::conversiones::avisame_si_baja" data-xiti-shared-n2="true" id="alert-price-down-btn" title="¿Cuánto pagarías por este inmueble? recibir aviso si baja de precio">Recibir aviso si baja de precio</a>
# </p>
# </div>
# </section>
# </article>
# </div>
# </div>
# <div class="ide-box-detail overlay-box">
# <article class="clearfix data-feature">
# <a class="data__logo" href="/data/"><span class="icon-font mb-regular"> <span class="icon-idealista-icon"></span> <span class="icon-data"></span> </span></a>
# <section class="data-features__container">
# <h3 class="ide-box-detail-h3">¿Cuánto vale este inmueble?</h3>
# <p>Te enviamos un informe con la estimación de precio para este inmueble y con información de la zona.</p>
# <p class="data-feature-link">
# <a class="" data-markup="detalle::link::product-1202" href="/flow/estimacion-de-precio?lang=es&amp;adId=95249555">Comprar informe de valoración de precio</a>
# </p>
# </section>
# </article>
# </div>
# </section>
# <div class="ide-box-detail overlay-box" id="mapWrapper">
# <div class="clearfix" id="headerMap">
# <h3 class="ide-box-detail-h3">Ubicación</h3>
# <ul>
# <li class="header-map-list">
# Calle de Caballero
# </li>
# <li class="header-map-list">
# Barrio Les Corts
# </li>
# <li class="header-map-list">
# Distrito Les Corts
# </li>
# <li class="header-map-list">
# Barcelona
# </li>
# <li class="header-map-list">
# Área de Barcelona, Barcelona
# </li>
# </ul>
# </div>
# <div id="map"></div>
# <div class="static-map-container" id="static-map-container">
# <div class="no-show-address-feedback">
# <span class="icon-feedbk-info"></span>
# <span class="no-show-address-feedback-text">Por privacidad, el anunciante no ha indicado la dirección, pero puedes contactarle para conocer la dirección del inmueble.</span>
# </div>
# <div class="static-map" id="static-map"><a class="showMap" data-markup-map-photo="detalle::map::photo" href="#"></a></div>
# <div id="static-map-text-link"><a class="static-map-text-link showMap icon-search" data-markup-map-link="detalle::map::link" href="#"><span>Ampliar mapa</span></a></div>
# </div>
# </div>
# <a id="statsPosition" name="statsPosition"></a>
# <div class="ide-box-detail overlay-box mb-jumbo" id="stats">
# <h3 class="ide-box-detail-h3">Estadísticas</h3>
# <p class="stats-text">Anuncio actualizado el 31 de enero</p>
# <a class="stats-link" href="#">Ver número de visitas y contactos de este anuncio</a>
# <div id="stop-fixed-contact-scroll"></div>
# </div>
# <div class="price-ref aditional-link" id="price-ref">
# <p class="aditional-link_title">
# <span>
# Índice de referencia de Cataluña: No especificado
# </span>
# <span class="price-ref-info icon-feedbk-info" id="price-ref-info"></span>
# </p>
# </div>
# <div class="aditional-link ellipsis" id="aditional-link">
# <h2 class="aditional-link_title txt-body mb-small">Enlace adicional</h2>
# <a class="link-withered icon-new-tab" data-markup="detalle::link-external-diagonalcasa" href="http://www.diagonalcasa.com/ficha/index.php?codigo=3373_10389326" rel="nofollow noopener" target="_blank" title="www.diagonalcasa.com/ficha/index.php?codigo=3373_10389326 se abre en nueva ventana">www.diagonalcasa.com/ficha/index.php?codigo=3373_10389326</a>
# </div>
# </main>
# <div class="detail-with-suggestions-wrapper" id="detailWithSuggestions"></div>
# <div class="idealista-banner-wrapper">
# </div>
# </div>
# </div>
# </div>
# <section class="links-block-home">
# <div class="content">
# <nav>
# <h3>
# ¿Buscas inmueble?
# </h3>
# <ul>
# <li>
# <a href="/" title="Buscador principal">
# Buscador principal
# </a>
# </li>
# <li>
# <a href="/pisos-bancos" title="Pisos de bancos">
# Pisos de bancos
# </a>
# </li>
# <li>
# <a href="/pisos-vpo" title="Vivienda protegida y VPO">
# Vivienda protegida y VPO
# </a>
# </li>
# <li>
# <a href="/properties-for-sale-in-spain" title="Viviendas en venta en España">
# Viviendas en venta en España
# </a>
# </li>
# <li>
# <a href="/long-term-rentals-in-spain" title="Viviendas en alquiler en España">
# Viviendas en alquiler en España
# </a>
# </li>
# <li>
# <a href="/pisos-en-alquiler" title="Casas y pisos en alquiler">
# Casas y pisos en alquiler
# </a>
# </li>
# <li>
# <a href="/pisos-compartidos" title="Pisos compartidos">
# Pisos compartidos
# </a>
# </li>
# <li>
# <a href="https://es.rentalia.com/" title="Rentalia, alquiler vacacional">
# Rentalia, alquiler vacacional
# </a>
# </li>
# <li>
# <a href="https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/" title="Informe de precios">
# Informe de precios
# </a>
# </li>
# <li>
# <a href="https://www.idealista.com/maps/" title="idealista maps">
# idealista maps
# </a>
# </li>
# <li>
# <a href="/luxury-homes-spain" title="Pisos y casas de lujo en venta en España">
# Pisos y casas de lujo en venta en España
# </a>
# </li>
# <li>
# <a href="/luxury-rentals-spain" title="Pisos y casas de lujo en alquiler en España">
# Pisos y casas de lujo en alquiler en España
# </a>
# </li>
# </ul>
# </nav>
# <nav>
# <h3>
# ¿Tienes un inmueble?
# </h3>
# <ul>
# <li>
# <a href="/info/publicar-anuncio" title="Pon tu anuncio gratis">
# Pon tu anuncio gratis
# </a>
# </li>
# <li>
# <a href="/particulares" title="Servicios para anunciantes particulares">
# Servicios para anunciantes particulares
# </a>
# </li>
# <li>
# <a href="/info/mejorar-foto-video" title="Mejorar las fotos de tu anuncio">
# Mejorar las fotos de tu anuncio
# </a>
# </li>
# <li>
# <a href="/certificadoenergetico/" title="Solicitar certificado energético">
# Solicitar certificado energético
# </a>
# </li>
# <li>
# <a href="/contratos-de-alquiler/" title="Crea gratis tu contrato de alquiler">
# Crea gratis tu contrato de alquiler
# </a>
# </li>
# <li>
# <a href="/base-datos-inquilinos-morosos/consultar-lista-morosos" title="Consulta si un inquilino es moroso">
# Consulta si un inquilino es moroso
# </a>
# </li>
# <li>
# <a href="/valoracion-de-inmuebles/" title="Valora gratis cualquier inmueble">
# Valora gratis cualquier inmueble
# </a>
# </li>
# <li>
# <a href="/que-inmobiliaria-elegir/" title="Vender tu piso con una agencia">
# Vender tu piso con una agencia
# </a>
# </li>
# <li>
# <a href="/base-datos-inquilinos-morosos/como-incluir-morosos" title="Notificar inquilino moroso">
# Notificar inquilino moroso
# </a>
# </li>
# <li>
# <a href="/como-vender-tu-casa/" title="Guía sobre cómo vender tu casa">
# Guía sobre cómo vender tu casa
# </a>
# </li>
# <li>
# <a href="https://www.idealista.com/energy/calculadora-de-ahorro-solar/" title="Calcular ahorro instalando paneles solares">
# Calcular ahorro instalando paneles solares
# </a>
# </li>
# </ul>
# </nav>
# <nav>
# <h3>
# ¿Eres profesional inmobiliario?
# </h3>
# <ul>
# <li>
# <a href="/nuevo-profesional" title="Publica tus inmuebles de profesional">
# Publica tus inmuebles de profesional
# </a>
# </li>
# <li>
# <a href="/login" title="¿Ya eres cliente? Entra en tu cuenta">
# ¿Ya eres cliente? Entra en tu cuenta
# </a>
# </li>
# <li>
# <a href="https://www.idealista.com/cursos/" title="Cursos inmobiliarios">
# Cursos inmobiliarios
# </a>
# </li>
# <li>
# <a href="/info/publicidad" title="Publicidad en idealista">
# Publicidad en idealista
# </a>
# </li>
# <li>
# <a href="/info/acuerdos-internacionales" title="Acuerdos internacionales">
# Acuerdos internacionales
# </a>
# </li>
# <li>
# <a href="https://www.idealista.com/tools/servicios" title="idealista/tools: software de gestión para inmobiliarias">
# idealista/tools: software de gestión para inmobiliarias
# </a>
# </li>
# <li>
# <a href="/tools/software-recomendado-para-inmobiliarias" title="Otros software recomendados">
# Otros software recomendados
# </a>
# </li>
# <li>
# <a href="/base-datos-inquilinos-morosos/consultar-lista-morosos" title="Registro inquilinos morosos">
# Registro inquilinos morosos
# </a>
# </li>
# <li>
# <a href="https://www.idealista.com/data/" title="idealista/data: tecnología para el análisis inmobiliario">
# idealista/data: tecnología para el análisis inmobiliario
# </a>
# </li>
# <li>
# <a href="https://www.avaibook.com" title="AvaiBook: software para gestionar tu alquiler vacacional">
# AvaiBook: software para gestionar tu alquiler vacacional
# </a>
# </li>
# </ul>
# </nav>
# </div>
# </section>
# <footer class="main-footer">
# <div class="content">
# <span class="icon-idealista-icon" role="img"></span>
# <div class="lang-selector lang-responsive">
# <span class="lang-selector--lang-selected icon-arrow-dropdown">
# <span class="flag lang-es"></span>
# <span class="lang-text">Español</span>
# </span>
# <ul class="lang-selector--lang-options" data-url-attribute="/user/update-user-language" data-user-authenticated="false">
# <li>
# <a data-markup="cambio::idioma::pie::ca" href="/ca/inmueble/95249555/" id="idioma-ca" rel="nofollow" value="ca">
# <span>
# <span class="flag lang-ca" role="img"></span>Català
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::pie::en" href="/en/inmueble/95249555/" id="idioma-en" rel="nofollow" value="en">
# <span>
# <span class="flag lang-en" role="img"></span>English
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::pie::fr" href="/fr/inmueble/95249555/" id="idioma-fr" rel="nofollow" value="fr">
# <span>
# <span class="flag lang-fr" role="img"></span>Français
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::pie::de" href="/de/inmueble/95249555/" id="idioma-de" rel="nofollow" value="de">
# <span>
# <span class="flag lang-de" role="img"></span>Deutsch
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::pie::it" href="/it/inmueble/95249555/" id="idioma-it" rel="nofollow" value="it">
# <span>
# <span class="flag lang-it" role="img"></span>Italiano
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::pie::pt" href="/pt/inmueble/95249555/" id="idioma-pt" rel="nofollow" value="pt">
# <span>
# <span class="flag lang-pt" role="img"></span>Português
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::pie::da" href="/da/inmueble/95249555/" id="idioma-da" rel="nofollow" value="da">
# <span>
# <span class="flag lang-da" role="img"></span>Dansk
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::pie::fi" href="/fi/inmueble/95249555/" id="idioma-fi" rel="nofollow" value="fi">
# <span>
# <span class="flag lang-fi" role="img"></span>Suomi
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::pie::no" href="/no/inmueble/95249555/" id="idioma-no" rel="nofollow" value="no">
# <span>
# <span class="flag lang-no" role="img"></span>Norsk
# ...
#         </div>
#
#         <p>
#             Los bancos suelen pedir una aportación mínima del <strong>{{=minLtvPercentage}}% del precio de compra.</strong>
#         </p>
#
#         <a href="#" data-simulator-url="" class="btn action expand go-to-simulator" target="_blank">
#             Calcular gastos
#         </a>
#
#         <div class="back-button-mortgages">
#             <a class="back-step1-btn" href="#">Volver al paso anterior</a>
#         </div>
#
# </script>
# <script id="contact-mortgages-step2-validation-tmpl" type="text/microtemplate">
#
#
#
#     <div class="feedback contextual full-width warning icon-feedbk-alert error-container">
#         <p>No es posible encontrar una hipoteca con esas condiciones</p>
#     </div>
#
#     {{showAllErrors}}
#         <ul class="styled-list">
#             <li>
#                 Los bancos no permiten que la <strong>edad</strong> del solicitante más joven sea <strong>superior a los 65 años.</strong>
#             </li>
#             <li>
#                 Para esta casa y con tu ahorro aportado, tendrías que pagar una mensualidad de <strong>{{=monthlyRate}}€ durante 30 años.</strong> Al superar el 40% de tus ingresos los bancos no te concederán la hipoteca.
#             </li>
#         </ul>
#     {{:showAllErrors}}
#         {{ageValid}}
#         {{:ageValid}}
#             <p>
#                 Los bancos no permiten que la <strong>edad</strong> del solicitante más joven sea <strong>superior a los 65 años.</strong>
#             </p>
#         {{/ageValid}}
#
#         {{debtRatioValid}}
#         {{:debtRatioValid}}
#             <p>
#                 Para esta casa y con tu ahorro aportado, tendrías que pagar una mensualidad de <strong>{{=monthlyRate}}€ durante 30 años.</strong> Al superar el 40% de tus ingresos los bancos no te concederán la hipoteca.
#             </p>
#         {{/debtRatioValid}}
#     {{/showAllErrors}}
#
#     <div class="back-button-mortgages">
#         <a id="back-step2-btn" href="#">Volver al paso anterior</a>
#     </div>
#
# </script>
# <script id="contact-mortgages-step2-low-income-validation-tmpl" type="text/microtemplate">
#
#         <div class="feedback contextual full-width warning icon-feedbk-alert error-container">
#             <p>No es posible encontrar una hipoteca con esas condiciones</p>
#         </div>
#
#         <p>
#             Los bancos con los que trabajamos requieren unos <strong>ingresos mínimos mensuales de 800€</strong> para conceder una hipoteca.
#         </p>
#
#         <a href="#" data-simulator-url="" class="btn action expand go-to-simulator" target="_blank">
#             Calcular gastos
#         </a>
#
#         <div class="back-button-mortgages">
#             <a id="back-step2-btn" href="#">Volver al paso anterior</a>
#         </div>
#
# </script>
# <script id="contact-mortgages-step2-contract-type-validation-tmpl" type="text/microtemplate">
#
#         {{hasNoActivityContract}}
#         <div class="feedback contextual full-width warning icon-feedbk-alert error-container">
#             <p>No es posible encontrar una hipoteca con esas condiciones</p>
#         </div>
#         {{/hasNoActivityContract}}
#
#         <p>
#             Los bancos requieren que al menos uno de los solicitantes tenga <strong>estabilidad laboral demostrable</strong> para conceder una hipoteca.
#         </p>
#
#         {{hasTemporalContract}}
#         <button id="temporal-to-step3-btn" type="button" class="btn action expand">Continuar</button>
#         {{/hasTemporalContract}}
#
#         <div class="back-button-mortgages">
#             <a id="back-step2-btn" href="#">Volver al paso anterior</a>
#         </div>
#
# </script>
# <script id="contact-mortgages-step2-country-validation-tmpl" type="text/microtemplate">
#
#         <div class="feedback contextual full-width warning icon-feedbk-alert error-container">
#             <p>No es posible encontrar una hipoteca con esas condiciones</p>
#         </div>
#         <p>
#
#
#
#             No tenemos productos para residentes en {{=countrySelected}}
#             <a href="{{=invalidCountryGuide}}" target="_blank">¿Por qué?</a>
#         </p>
#
#         <div class="back-button-mortgages">
#             <a id="back-step2-btn" href="#">Volver al paso anterior</a>
#         </div>
#
# </script>
# <script id="show-more-photos-tmpl" type="text/microtemplate">
#
# 		<div id="show-more-photos-button" class="button overlay-box">
# 			<a class="btn regular more-photos" data-markup="seePhotos">
# 				Ver {{=hiddenPhotosLeft}} fotos siguientes
# 			</a>
# 		</div>
#
# </script>
# <script id="saving-alert-tmpl" type="text/microtemplate">
#
#
#
#
#
#
#
#
#
#
#
#
#
# {{lessSavingAlert}}
# 	Necesitas cubrir la aportación mínima que piden los bancos. <a id="link-set-saving" href="" data-markup='detalle::mortgages::savings-adjust'>Ajustar</a>.
# {{/lessSavingAlert}}
#
# {{bigSavingWarning}}
# 	El ahorro aportado no puede ser mayor que el precio del inmueble
# {{/bigSavingWarning}}
#
# </script>
# <script id="saving-warning-tmpl" type="text/microtemplate">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# El ahorro aportado no puede ser mayor que el precio del inmueble
#
# </script>
# <script id="minmortgages-alert-tmpl" type="text/microtemplate">
#
#     <div class="feedback contextual full-width neutral-temp icon-feedbk-info">
#
#
#
#
#
#
#
#
#
#
#
#
# Los bancos no suelen dar hipotecas si el importe de esta es inferior a {{=minMortgages}}€
#
#     </div>
#
# </script>
# <script id="minhouseprice-alert-tmpl" type="text/microtemplate">
#
#     <div class="feedback contextual full-width neutral-temp icon-feedbk-info">
#
#
#
#
#
#
#
#
#
#
#
#
# Los bancos no suelen dar hipotecas para viviendas inferiores a {{=minHousePrice}}€
#
#     </div>
# </script>
# <script id="expenses-glossary-tmpl" type="text/microtemplate">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div id="expenses-glossary-content" class="expenses-glossary">
# 	<p class="h3-simulated txt-bold mb-regular">Impuestos y gastos</p>
# 	<p>Cálculo teniendo en cuenta la localización y condición del inmueble.</p>
# 	<table id="buying-expenses">
# 		<thead>
# 			<tr>
# 				<th class="txt-bold" colspan="3">Gastos de la Compra </th>
# 			</tr>
# 		</thead>
# 		<tbody>
# 			<tr>
# 				<td>Notaría : </td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><span>{{=buyingExpenses.notaryExpenses}} &euro;</span></td>
# 			</tr>
# 			<tr>
# 				<td>Registro: </td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><span>{{=buyingExpenses.registryExpenses}} &euro;</span></td>
# 			</tr>
# 			<tr>
# 				<td>Gestoría: </td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><span>{{=buyingExpenses.processAgencyExpenses}} &euro;</span></td>
# 			</tr>
# 			<tr>
# 				<td>Impuestos: </td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><span>{{=buyingExpenses.taxesExpenses.total}} &euro;</span></td>
# 			</tr>
# 			<tr class="total">
# 				<td class="result">Total: </td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><span>{{=buyingExpenses.total}} &euro;</span></td>
# 			</tr>
# 		</tbody>
# 	</table>
#
# 	<table id="loan-expenses">
# 		<thead>
# 			<tr>
# 				<th class="txt-bold" colspan="3">Gastos de la Hipoteca</th>
# 			</tr>
# 		</thead>
# 		<tbody>
# 			<tr>
# 				<td>Notaría : </td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><span>{{=loanExpenses.notaryExpenses}} &euro;</span></td>
# 			</tr>
# 			<tr>
# 				<td>Registro: </td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><span>{{=loanExpenses.registryExpenses}} &euro;</span></td>
# 			</tr>
# 			<tr>
# 				<td>Gestoría: </td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><span>{{=loanExpenses.processAgencyExpenses}} &euro;</span></td>
# 			</tr>
# 			<tr>
# 				<td>Impuestos: </td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><span>{{=loanExpenses.taxesExpenses.total}} &euro;</span></td>
# 			</tr>
# 			<tr class="total">
# 				<td class="result">Total: </td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><span>{{=loanExpenses.total}} &euro;</span></td>
# 			</tr>
# 		</tbody>
# 	</table>
#
# 	<table id="results">
# 		<tbody>
# 			<tr class="total">
# 				<td><strong>Gastos totales</strong></td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><strong>{{=totalExpenses}} &euro;</strong></td>
# 			</tr>
# 			<tr>
# 				<td>Gastos de Tasación </td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><span>{{=tasationExpenses}} &euro;</span></td>
# 			</tr>
# 		</tbody>
# 	</table>
#
# 	<p class="txt-result">Este es un cálculo orientativo no vinculante. Es necesario remitir la información detallada al banco para calcular la cantidad exacta.</p>
# </div>
#
# </script>
# <script id="rate-type-info-tmpl" type="text/microtemplate">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="mortgages-modal-content-container">
# 	<h3 class="txt-medium txt-bold mb-small">¿Cómo hemos calculado el interés?</h3>
# 	<p>Este tipo de interés es una referencia media del mercado hipotecario.</p>
# 	<p><strong>Fijo: </strong>es el tipo de interés que se mantiene constante durante toda la vida del préstamo. Es más bajo cuando menor sea el plazo.</p>
# 	<p><strong>Variable: </strong>la cuota variará a lo largo de la vida del préstamo en función a las fluctuaciones del euribor</p>
# </div>
#
# </script>
# <script id="savings-info-tmpl" type="text/microtemplate">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="mortgages-modal-content-container">
# 	<p></p>
# </div>
#
# </script>
# <script data-title="" id="affida-contact-mortgages-tmpl" type="text/microtemplate">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <section class="affida-contact">
#     <div class="modal-inner">
#         <form id="send-contact-form" method="post" novalidate>
#
#             <div class="logo-idealista">
#                 <a href="/hipotecas/">
#
#
#
#                             <span class="icon-idealista-icon"></span>
#
#
#                     <span class="icon-hipotecas"></span>
#                 </a>
#             </div>
#             <div class="item-form affida-items">
#                 <div class="item-form">
#                     <label>
#                         <span>Precio inmueble</span>
#                         <span class="desc-container">
#                             <span class="desc">Euros</span>
#                             <input type="tel" class="property-price" name="property-price" maxlength="9" data-min="0" data-max="2000000" data-validation="required number" data-message-required="Necesitamos conocer este dato" value="{{=buyingPrice}}">
#                         </span>
#                     </label>
#                 </div>
#
#                 <div class="item-form">
#                     <label>
#                         <span class="show-mobile">Ahorro aportado</span>
#                         <span class="show-desktop">Ahorro aportado</span>
#                         <span class="desc-container">
#                             <span class="desc">Euros</span>
#                             <input type="tel" class="savings-input" name="savings" maxlength="9" data-min="0" data-max="2000000" data-validation="required number" data-message-required="Necesitamos conocer este dato" value="{{=savings}}" />
#
#                         </span>
#                     </label>
#                 </div>
#                 <div class="item-form">
#                     <label>
#                         <span>Term (years)</span>
#                         <select class="duration-in-years" name="duration-in-years" data-validation="select" data-message-select="Necesitamos conocer este dato">
#                             <option value="">Seleccionar</option>
#                             <option value="30" {{y30}} selected {{/y30}}>30</option>
#                             <option value="25" {{y25}} selected {{/y25}}>25</option>
#                             <option value="20" {{y20}} selected {{/y20}}>20</option>
#                             <option value="15" {{y15}} selected {{/y15}}>15</option>
#                             <option value="10" {{y10}} selected {{/y10}}>10</option>
#                         </select>
#                     </label>
#                 </div>
#                 <div class="item-form">
#                     <label>
#                         Tipo de interés
#                         <ul class="horizontal-list">
#                             <li>
#                                 <label class="input-radio">
#                                     <input type="radio" name="tax-type" value="2" {{variableRate}} checked="checked" {{/variableRate}}>
#                                     <span>
# 										<span>Variable</span>
# 									</span>
#                                 </label>
#                             </li>
#                             <li>
#                                 <label class="input-radio">
#                                     <input type="radio" name="tax-type" value="1" {{fixedRate}} checked="checked" {{/fixedRate}}>
#                                     <span>
# 										<span>Fijo</span>
# 									</span>
#                                 </label>
#                             </li>
#                         </ul>
#                     </label>
#                 </div>
#             </div>
#             <div class="affida-offer">
#                 <div class="affida-offer__main">
#                     <p class="txt-big">Nuestra mejor oferta</p>
#                     <p class="txt-bold txt-big affida-offer__monthly"><span id="js-calculated-monthly">3901</span> €/mes</p>
#                 </div>
#                 <div class="affida-offer__details">
#                     <p>
#                         <span class="affida-offer__details__condition">Ahorro aportado:</span>
#                         <span><span id="js-calculated-savings"></span>€</span>
#                     </p>
#                     <p>
#                         <span class="affida-offer__details__condition">Importe hipoteca:</span>
#                         <span><span id="js-calculated-loan"></span>€</span>
#                     </p>
#                     <p>
#                         <span class="affida-offer__details__condition">Interés:</span>
#                         <span><span id="js-calculated-tax"></span>%</span>
#                     </p>
#                 </div>
#             </div>
#             <div id="minmortgages-alert-modal"></div>
#             <div class="affida-offer__btn-container">
#                 <a href="#" id="js-affida-form" class="btn action fullwidth send-form">Encuentra tu hipoteca </a>
#             </div>
#         </form>
#         <div class="affida-legal">
#             <p>Affida S.r.l. El tipo de interés indicado es el más ventajoso disponible entre las entidades de crédito que mantienen acuerdos con Affida S.r.l. y es el resultado de un cálculo algorítmico de los préstamos hipotecarios. La cuota se publica sólo a título informativo y puede ser confirmada o recalculada tras el asesoramiento y el análisis de Affida S.r.l. y de acuerdo con los parámetros de crédito de los bancos y/u otros acreedores. Póngase en contacto con uno de los más de 200 agentes personales de Affida presentes en todo el territorio nacional para obtener asesoramiento y el cupón "La Casa en Tasca", un documento oficial emitido por una institución financiera socia de Affida S.r.l. que le dará la certeza de obtener el préstamo hipotecario en las condiciones establecidas. Las hojas de información están disponibles en la red de agencias de Affida S.r.l. o en el sitio web de Affida.credit </p>
#         </div>
#     </div>
# </section>
#
#
# </script>
# <script id="comment-translation-tmpl" type="text/microtemplate">
#
#         <div class="translationWarning">
#             <span>{{=message}}</span>
#             <span class="viewOriginalComment"><a href="#" data-lang="es">{{=messageLink}}</a></span>
#             <div class="googleTranslateLogo"><img src="https://st1.idealista.com/static/common/release/detail/resources/img/google-translate.png"></div>
#         </div>
#
# </script>
# <script id="expander-button-tmpl" type="text/microtemplate">
#
#             <div class="expanderParent">
#                 <span class="icon-arrow-right"></span>
#                 <a href="#" class="expander">Leer comentario completo</a>
#             </div>
#
# </script>
# </body>
# </html>

# %%
'''
h1 --> span --> text # titulo

span --> class= "main-info__title-block" --> span --> text # barrio ciudad  

div --> class= "info-data" --> span --> text # precio alquiler



'''
# Out:
# '\nh1 --> span --> text # titulo\n\nspan --> class= "main-info__title-block" --> span --> text # barrio ciudad  \n\ndiv --> class= "info-data" --> span --> text # precio alquiler\n\n\n\n'

# %%
titulo = soup.find('h1').text.strip() # el nombre esta h1, formato text, strip espacios
titulo
# Out:
# 'Alquiler de Piso en calle de Caballero'

# %%
localizacion = soup.find('span',{'class':'main-info__title-block'}).find("span").text # esta dentro de un span con class: main...
# dentro otro span esta la localizaion
localizacion
# Out:
# 'Les Corts, Barcelona'

# %%
precio = int(soup.find('div',{'class':'info-data'}).find('span').text.strip(' €/mes')) # ojo quizas se queja
precio
# Out:
# 890

# %%
soup.find('div', {'class':'info-features'}).text.replace('\n',"")
# Out:
# '81m²3hab.Planta 3ªcon ascensor'
